# %%
# Load dotenv
from dotenv import load_dotenv
import os

load_dotenv()

LEGISLATION_URL_PREFIX = os.getenv("LEGISLATION_URL_PREFIX")
LEGISLATION_URI_LIST_FILE = os.getenv("LEGISLATION_URI_LIST_FILE")
JSON_OUTPUT_DIR = os.getenv("JSON_OUTPUT_DIR", "json_out")
DEPTH_LIMIT = int(os.getenv("DEPTH_LIMIT", 2))

# %%
import os
import requests
from bs4 import BeautifulSoup
import json
from collections import deque


class LegislationCrawler:
    def __init__(self, max_depth=2):
        self.max_depth = max_depth
        self.visited_urls = set()
        self.queue = deque()

        os.makedirs(".cache", exist_ok=True)
        os.makedirs(JSON_OUTPUT_DIR, exist_ok=True)

    def get_safe_filename(self, url):
        clean_url = url.split("://")[-1].replace(LEGISLATION_URL_PREFIX + "/", "")
        return clean_url.replace("/", "_")

    def normalize_url(self, uri):
        if not uri:
            return None
        clean_uri = uri.replace("/id/", "/")
        clean_uri = clean_uri.rstrip("/")
        if not clean_uri.endswith("data.xml"):
            return f"{clean_uri}/data.xml"
        return clean_uri

    def clean_url(self, url):
        return url.replace("/id/", "/").rstrip("/")

    def extract_identifier(self, soup):
        identifier = {}
        title = soup.find("dc:title")
        identifier["title"] = title.text.strip() if title else None
        description = soup.find("dc:description")
        identifier["description"] = description.text.strip() if description else None
        publisher = soup.find("dc:publisher")
        identifier["publisher"] = publisher.text.strip() if publisher else None
        modified = soup.find("dc:modified")
        identifier["modified"] = modified.text.strip() if modified else None
        identifier_tag = soup.find("dc:identifier")
        identifier["uri"] = identifier_tag.text.strip() if identifier_tag else None
        valid = soup.find("dct:valid")
        identifier["valid_date"] = valid.text.strip() if valid else None
        return identifier

    def extract_super(self, soup):
        super = {}
        supersedes = soup.find("ukm:Supersedes")
        if supersedes:
            super["supersedes"] = self.clean_url(supersedes.get("URI"))
        superseded_by = soup.find("ukm:SupersededBy")
        if superseded_by:
            super["superseded_by"] = self.clean_url(superseded_by.get("URI"))

        return super

    def extract_metadata(self, soup):
        metadata = {}
        metadata_block = soup.find(
            ["ukm:PrimaryMetadata", "ukm:SecondaryMetadata", "ukm:EUMetadata"]
        )
        if not metadata_block:
            return metadata

        year = metadata_block.find("ukm:Year")
        metadata["year"] = year.get("Value") if year else None
        number = metadata_block.find("ukm:Number")
        metadata["number"] = number.get("Value") if number else None
        enactment = metadata_block.find("ukm:EnactmentDate")
        metadata["enactment_date"] = enactment.get("Date") if enactment else None
        status = metadata_block.find("ukm:DocumentStatus")
        metadata["status"] = status.get("Value") if status else None
        isbn = metadata_block.find("ukm:ISBN")
        metadata["isbn"] = isbn.get("Value") if isbn else None
        category = metadata_block.find("ukm:DocumentCategory")
        metadata["category"] = category.get("Value") if category else None
        coming_into_force = metadata_block.find("ukm:ComingIntoForce")
        if coming_into_force:
            date_tag = coming_into_force.find("ukm:DateTime")
            metadata["coming_into_force"] = (
                date_tag.get("Date").strip() if date_tag else None
            )

        unapplied_effects_list = []
        for effect in metadata_block.find_all("ukm:UnappliedEffect"):
            effect_data = {
                "effect_id": effect.get("EffectId"),
                "type": effect.get("Type"),
                "affected_provisions": effect.get("AffectedProvisions"),
                "affecting_provisions": effect.get("AffectingProvisions"),
                "requires_applied": effect.get("RequiresApplied") == "true",
                "notes": effect.get("Notes"),
                "modified_date": effect.get("Modified"),
                "affecting_title": None,
                "in_force_date": None,
                "in_force_qualification": None,
            }
            affecting_title = effect.find("ukm:AffectingTitle")
            if affecting_title:
                effect_data["affecting_title"] = affecting_title.text.strip()
            in_force = effect.find("ukm:InForce")
            if in_force:
                if in_force.get("Date"):
                    effect_data["in_force_date"] = in_force.get("Date")
                elif in_force.get("Prospective") == "true":
                    effect_data["in_force_date"] = "Prospective"
                effect_data["in_force_qualification"] = in_force.get(
                    "Qualification"
                ) or in_force.get("OtherQualification")
            unapplied_effects_list.append(effect_data)

        metadata["unapplied_effects"] = unapplied_effects_list
        return metadata

    def _get_xml_soup(self, xml_url, safe_name, current_depth):
        cache_filepath = os.path.join(".cache", safe_name)

        if os.path.exists(cache_filepath):
            print(f"[{current_depth}] Loading from cache: {cache_filepath}")
            with open(cache_filepath, "rb") as f:
                xml_content = f.read()
        else:
            print(f"[{current_depth}] Fetching network data: {xml_url}")
            try:
                response = requests.get(xml_url)
                response.raise_for_status()
                xml_content = response.content
                temp_soup = BeautifulSoup(xml_content, "xml")
                xml_content = temp_soup.prettify(encoding="utf-8")
                with open(cache_filepath, "wb") as f:
                    f.write(xml_content)
            except requests.exceptions.RequestException as e:
                print(f"Failed to fetch {xml_url}: {e}")
                return None
        return BeautifulSoup(xml_content, "xml")

    def _extract_commentaries(self, soup, current_depth, found_citations):
        commentaries_map = {}
        for comm in soup.find_all("Commentary"):
            comm_id = comm.get("id")
            if not comm_id:
                continue

            full_text = comm.get_text(separator=" ", strip=True)
            citations = []

            for cit in comm.find_all("Citation"):
                cit_uri = cit.get("URI")
                citations.append(
                    {
                        "id": cit.get("id"),
                        "uri": cit_uri,
                        "title": cit.get("Title"),
                        "class": cit.get("Class"),
                        "year": cit.get("Year"),
                        "number": cit.get("Number"),
                        "text": cit.text.strip(),
                    }
                )
                if cit_uri and current_depth < self.max_depth:
                    found_citations.add(cit_uri)

            citation_subrefs = []
            for subref in comm.find_all("CitationSubRef"):
                citation_subrefs.append(
                    {
                        "id": subref.get("id"),
                        "uri": subref.get("URI"),
                        "citation_ref": subref.get("CitationRef"),
                        "section_ref": subref.get("SectionRef"),
                        "text": subref.text.strip(),
                    }
                )

            commentaries_map[comm_id] = {
                "type": comm.get("Type"),
                "text": full_text,
                "citations": citations,
                "citation_subrefs": citation_subrefs,
            }
        return commentaries_map

    def _resolve_commentaries(self, element, commentaries_map, exclude_parent=None):
        resolved = []
        for cref in element.find_all("CommentaryRef"):
            if exclude_parent and cref.find_parent(exclude_parent) is not None:
                continue
            ref_id = cref.get("Ref")
            if ref_id in commentaries_map:
                resolved.append({"ref_id": ref_id, **commentaries_map[ref_id]})
        return resolved

    def _get_joined_text(self, element):
        return " ".join(
            [t.get_text(separator=" ", strip=True) for t in element.find_all("Text")]
        )

    def _extract_body_parts(self, soup, commentaries_map):
        document_tree = {}
        body_p1s = [p1 for p1 in soup.find_all("P1") if not p1.find_parent("Schedules")]

        for idx, section in enumerate(body_p1s, start=1):
            part = section.find_parent("Part")
            chapter = section.find_parent("Chapter")
            p1group = section.find_parent("P1group")

            part_num = (
                part.find("Number").text.strip()
                if part and part.find("Number")
                else "No Part"
            )
            part_uri = part.get("DocumentURI") if part else None
            part_restrict_start_date = part.get("RestrictStartDate") if part else None
            part_restrict_end_date = part.get("RestrictEndDate") if part else None
            part_status = part.get("Status") if part else None
            part_title = (
                part.find("Title").text.strip() if part and part.find("Title") else None
            )
            chapter_uri = chapter.get("DocumentURI") if chapter else None
            chapter_restrict_start_date = (
                chapter.get("RestrictStartDate") if chapter else None
            )
            chapter_restrict_end_date = (
                chapter.get("RestrictEndDate") if chapter else None
            )
            chapter_status = chapter.get("Status") if chapter else None
            chapter_num = (
                chapter.find("Number").text.strip()
                if chapter and chapter.find("Number")
                else "No Chapter"
            )
            chapter_title = (
                chapter.find("Title").text.strip()
                if chapter and chapter.find("Title")
                else None
            )

            chap_dict_key = chapter_uri or chapter_num

            if part_num not in document_tree:
                document_tree[part_num] = {
                    "title": part_title,
                    "part_uri": part_uri,
                    "restrict_start_date": part_restrict_start_date,
                    "restrict_end_date": part_restrict_end_date,
                    "status": part_status,
                    "chapters": {},
                }

            if chap_dict_key not in document_tree[part_num]["chapters"]:
                document_tree[part_num]["chapters"][chap_dict_key] = {
                    "chapter_uri": chapter_uri,
                    "chapter_number": (
                        chapter_num if chapter_num != "No Chapter" else None
                    ),
                    "restrict_start_date": chapter_restrict_start_date,
                    "restrict_end_date": chapter_restrict_end_date,
                    "status": chapter_status,
                    "title": chapter_title,
                    "sections": [],
                }

            section_num = (
                section.find("Pnumber").text.strip()
                if section.find("Pnumber")
                else None
            )
            section_title = (
                p1group.find("Title").text.strip()
                if p1group and p1group.find("Title")
                else None
            )
            section_restrict_start_date = (
                p1group.get("RestrictStartDate") if p1group else None
            )
            section_restrict_end_date = (
                p1group.get("RestrictEndDate") if p1group else None
            )
            section_restrict_extent = p1group.get("RestrictExtent") if p1group else None

            section_data = {
                "order": idx,
                "section_number": section_num,
                "title": section_title,
                "uri": section.get("DocumentURI") or section.get("id"),
                "restrict_start_date": section_restrict_start_date,
                "restrict_end_date": section_restrict_end_date,
                "restrict_extent": section_restrict_extent,
                "commentaries": self._resolve_commentaries(
                    section, commentaries_map, exclude_parent="P2"
                ),
                "paragraphs": [],
            }

            paragraphs = section.find_all(["P2", "P3", "P4"])
            if not paragraphs:
                section_data["text"] = self._get_joined_text(section)
            else:
                for idx, para in enumerate(paragraphs, start=1):
                    para_num = (
                        para.find("Pnumber").text.strip()
                        if para.find("Pnumber")
                        else None
                    )
                    section_data["paragraphs"].append(
                        {
                            "order": idx,
                            "paragraph_number": para_num,
                            "text": self._get_joined_text(para),
                            "uri": para.get("DocumentURI") or para.get("id"),
                            "commentaries": self._resolve_commentaries(
                                para, commentaries_map
                            ),
                        }
                    )

            document_tree[part_num]["chapters"][chap_dict_key]["sections"].append(
                section_data
            )

        parts_list = []
        for part_idx, (p_num, p_data) in enumerate(document_tree.items(), start=1):
            part_obj = {
                "order": part_idx,
                "part_number": p_num if p_num != "No Part" else None,
                "uri": p_data["part_uri"],
                "restrict_start_date": p_data["restrict_start_date"],
                "restrict_end_date": p_data["restrict_end_date"],
                "status": p_data["status"],
                "title": p_data["title"],
                "chapters": [],
            }
            for chap_idx, (chap_key, c_data) in enumerate(
                p_data["chapters"].items(), start=1
            ):
                part_obj["chapters"].append(
                    {
                        "order": chap_idx,
                        "chapter_number": c_data["chapter_number"],
                        "uri": c_data["chapter_uri"],
                        "restrict_start_date": c_data["restrict_start_date"],
                        "restrict_end_date": c_data["restrict_end_date"],
                        "status": c_data["status"],
                        "title": c_data["title"],
                        "sections": c_data["sections"],
                    }
                )
            parts_list.append(part_obj)

        return parts_list

    def _extract_schedules(self, soup, commentaries_map):
        schedules_list = []
        schedules_root = soup.find("Schedules")

        if not schedules_root:
            return schedules_list

        for sched_idx, schedule in enumerate(
            schedules_root.find_all("Schedule"), start=1
        ):
            sched_num = (
                schedule.find("Number").text.strip()
                if schedule.find("Number")
                else None
            )
            sched_title_node = schedule.find("Title")
            sched_title = (
                sched_title_node.get_text(strip=True) if sched_title_node else None
            )
            sched_ref = (
                schedule.find("Reference").text.strip()
                if schedule.find("Reference")
                else None
            )

            sched_obj = {
                "order": sched_idx,
                "schedule_number": sched_num,
                "title": sched_title,
                "reference": sched_ref,
                "uri": schedule.get("DocumentURI") or schedule.get("id"),
                "paragraphs": [],
            }

            for p1_idx, p1 in enumerate(schedule.find_all("P1"), start=1):
                p1_num = p1.find("Pnumber").text.strip() if p1.find("Pnumber") else None
                pblock = p1.find_parent("Pblock")
                pblock_title = (
                    pblock.find("Title").get_text(strip=True)
                    if pblock and pblock.find("Title")
                    else None
                )

                p1_data = {
                    "order": p1_idx,
                    "paragraph_number": p1_num,
                    "crossheading": pblock_title,
                    "uri": p1.get("DocumentURI") or p1.get("id"),
                    "commentaries": self._resolve_commentaries(
                        p1, commentaries_map, exclude_parent="P2"
                    ),
                    "subparagraphs": [],
                }

                p2s = p1.find_all("P2")
                if not p2s:
                    p1_data["text"] = self._get_joined_text(p1)
                else:
                    for p2_idx, p2 in enumerate(p2s, start=1):
                        p2_num = (
                            p2.find("Pnumber").text.strip()
                            if p2.find("Pnumber")
                            else None
                        )
                        p1_data["subparagraphs"].append(
                            {
                                "order": p2_idx,
                                "subparagraph_number": p2_num,
                                "text": self._get_joined_text(p2),
                                "uri": p2.get("DocumentURI") or p2.get("id"),
                                "commentaries": self._resolve_commentaries(
                                    p2, commentaries_map
                                ),
                            }
                        )

                sched_obj["paragraphs"].append(p1_data)
            schedules_list.append(sched_obj)
        return schedules_list

    def _extract_explanatory_notes(self, soup, current_depth, found_citations):
        notes_root = soup.find("ExplanatoryNotes")
        if not notes_root:
            return None

        notes_uri = notes_root.get("DocumentURI") or notes_root.get("IdURI")

        paragraphs = []
        for p in notes_root.find_all("P"):
            p_text = self._get_joined_text(p)

            citations = []
            for cit in p.find_all("Citation"):
                cit_uri = cit.get("URI")
                citations.append(
                    {
                        "id": cit.get("id"),
                        "uri": cit_uri,
                        "title": cit.get("Title"),
                        "class": cit.get("Class"),
                        "year": cit.get("Year"),
                        "number": cit.get("Number"),
                        "text": cit.text.strip(),
                    }
                )
                if cit_uri and current_depth < self.max_depth:
                    found_citations.add(cit_uri)

            paragraphs.append({"text": p_text, "citations": citations})

        return {"uri": notes_uri, "paragraphs": paragraphs}

    def fetch_and_parse(self, target_url, current_depth):
        xml_url = self.normalize_url(target_url)
        if not xml_url:
            return None

        base_identifying_url = xml_url.replace("/data.xml", "")
        if base_identifying_url in self.visited_urls:
            return None

        self.visited_urls.add(base_identifying_url)

        safe_name = self.get_safe_filename(xml_url)
        soup = self._get_xml_soup(xml_url, safe_name, current_depth)
        if not soup:
            return None

        identifier = self.extract_identifier(soup)
        metadata = self.extract_metadata(soup)
        super = self.extract_super(soup)

        doc_year = metadata.get("year") or "unknown_year"
        year_dir = os.path.join(JSON_OUTPUT_DIR, str(doc_year))
        os.makedirs(year_dir, exist_ok=True)
        json_filepath = os.path.join(year_dir, safe_name.replace(".xml", ".json"))

        found_citations = set()
        commentaries_map = self._extract_commentaries(
            soup, current_depth, found_citations
        )

        parts_list = self._extract_body_parts(soup, commentaries_map)
        schedules_list = self._extract_schedules(soup, commentaries_map)
        explanatory_notes = self._extract_explanatory_notes(
            soup, current_depth, found_citations
        )

        final_json_structure = {
            "legislation_url": identifier.get("uri"),
            "identifier": identifier,
            "super": super,
            "metadata": metadata,
            "parts": parts_list,
            "schedules": schedules_list,
            "explanatory_notes": explanatory_notes,
        }

        with open(json_filepath, "w", encoding="utf-8") as f:
            f.write(json.dumps(final_json_structure, indent=4))

        for cit_url in found_citations:
            normalized = self.normalize_url(cit_url)
            if (
                normalized
                and normalized.replace("/data.xml", "") not in self.visited_urls
            ):
                self.queue.append((cit_url, current_depth + 1))

        if super.get("supersedes"):
            self.queue.append(
                (super.get("supersedes"), current_depth)
            )  # Leave at current depth as we want superseeds to always be retrieved.
        if super.get("superseded_by"):
            self.queue.append((super.get("superseded_by"), current_depth))

    def crawl(self, start_url):
        self.queue.append((start_url, 0))

        while self.queue:
            current_url, depth = self.queue.popleft()
            self.fetch_and_parse(current_url, depth)

        print(
            f"\nCrawl complete. Processed {len(self.visited_urls)} unique pieces of legislation."
        )

# %%
crawler = LegislationCrawler(max_depth=DEPTH_LIMIT)

# Read LEGISLATION_URI_LIST_FILE and process each URI
with open(LEGISLATION_URI_LIST_FILE, "r") as f:
    legislation_uris = [line.strip() for line in f if line.strip()]
for uri in legislation_uris:
    full_url = f"{LEGISLATION_URL_PREFIX}{uri}"
    print(f"\nProcessing legislation: {full_url}")
    crawler.crawl(full_url)
# Out:
# Processing legislation: http://legislation.gov.uk/ukpga/2020/14
# [0] Loading from cache: .cache/legislation.gov.uk_ukpga_2020_14_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_92_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2024_3_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_113_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_531_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_500_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2022_3_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_434_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_1130_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_740_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2023_30_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2021_26_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_897_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2025_8_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_356_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_286_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_1012_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_912_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2004_12_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2022_7_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_419_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2020_14_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_1317_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2020_17_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_1134_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1990_43_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2003_44_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1980_43_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1998_46_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2017_32_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_1321_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2024_12_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_1164_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_69_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_569_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1979_5_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_884_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_96_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_522_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_918_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_589_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_1132_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_1277_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_799_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_149_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1994_23_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_128_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_874_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_130_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_1278_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_1417_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_399_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_440_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_770_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2023_1_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_1409_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukdsi_2019_9780111190142_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukdsi_2025_9780348270761_data.xml
#
# Crawl complete. Processed 58 unique pieces of legislation.
#
# Processing legislation: http://legislation.gov.uk/ukpga/2010/4
# [0] Loading from cache: .cache/legislation.gov.uk_ukpga_2010_4_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_1817_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_636_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2015_33_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_734_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_964_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_1399_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_716_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_266_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_464_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_1253_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_674_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_952_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2014_14_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_364_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2010_31_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2011_24_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_518_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_2977_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_wsi_2018_34_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_3327_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_1785_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_wsi_2018_101_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2012_14_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_3209_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_2395_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_724_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1545_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2017_10_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_1270_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_628_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_78_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2003_1_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_1179_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_79_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2017_4_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2010_36_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2009_4_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2017_22_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2012_21_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_818_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2011_25_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2007_3_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_2971_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2010_4_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2013_2_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2018_22_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_1388_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2010_8_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2014_21_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_1815_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2015_21_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_1087_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_286_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_689_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2022_40_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_2595_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_1458_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2006_964_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_402_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_1938_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2011_11_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2010_13_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_1072_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_460_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_1271_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_2885_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_736_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_63_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2016_898_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2020_12_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1981_63_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_744_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2006_3296_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_662_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_asp_2013_11_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2022_31_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_463_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1998_36_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_98_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_57_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_2228_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_200_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_anaw_2017_1_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2002_29_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2014_7_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2018_3_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_1662_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2020_1_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2013_29_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ssi_2015_108_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_1962_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_518_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_855_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2014_26_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_665_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2015_11_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2016_24_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2010_33_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2020_26_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2019_1_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1495_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2011_20_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2005_5_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_465_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_2999_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_143_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2003_14_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1642_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_2902_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_700_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1992_12_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_685_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_725_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_245_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_1078_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_105_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2023_53_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_555_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_1174_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_2819_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_423_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukdsi_2013_9780111533819_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2012_7_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_500_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2014_2_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_515_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1991_2034_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2006_41_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukdsi_2012_9780111519394_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukdsi_2023_9780348252859_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1986_45_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_82_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1350_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_201_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2000_8_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukdsi_2021_9780348222814_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2008_9_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1994_9_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukdsi_2012_9780111519134_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2006_46_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/european/directive/1977/0091/data.xml
# Failed to fetch http://www.legislation.gov.uk/european/directive/1977/0091/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/european/directive/1977/0091/data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukdsi_2012_9780111519981_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_323_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_1822_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2008_566_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ssi_2018_253_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1996_52_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2008_17_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_1164_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_779_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_744_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_322_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2023_29_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_asp_2018_13_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_2007_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_64_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_1821_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_2352_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_687_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_1068_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_686_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_631_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_2042_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_anaw_2016_3_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_2401_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_2314_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_2853_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2016_1007_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_1924_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_850_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_2407_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_2398_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_892_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_3043_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_wsi_2017_714_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_2329_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_2406_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_1923_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_475_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_1206_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_252_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_2654_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_176_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_978_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1998_3175_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1988_1_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2005_11_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1970_9_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_1901_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_1896_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_622_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2015_1_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_607_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_938_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_1983_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_664_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_1999_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_1959_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_3008_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_587_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_2244_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_279_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_3009_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2016_606_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukdsi_2013_9780111106273_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2004_4_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2005_1868_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_215_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2002_1142_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1992_3122_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_175_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2003_1114_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_486_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_2925_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1987_2108_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_408_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1992_3222_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2009_10_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2003_3220_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_59_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2000_794_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1544_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1988_809_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_1978_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1992_3156_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1412_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1641_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1992_3130_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2005_762_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_1249_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1993_2001_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_1458_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_3241_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_1248_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1999_16_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_1215_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2004_3148_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1984_746_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2002_23_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_1376_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_1043_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2001_574_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1992_3193_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2005_2114_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2006_3157_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1995_958_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1995_3147_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_730_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1995_281_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1995_291_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_60_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1992_3132_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2000_258_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1996_1250_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1995_1268_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_1328_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_2953_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_295_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2002_1935_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1992_3111_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_2923_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1995_4_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_701_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1995_1269_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_1214_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1995_2518_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2006_2187_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2005_2231_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1997_1616_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_91_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2007_1418_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1546_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1999_3121_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_108_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1431_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_513_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1996_8_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_1967_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2004_3140_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1996_1255_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_32_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_467_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2000_11_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2001_24_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2006_133_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_495_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2016_1036_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2018_24_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2008_787_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_41_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_1148_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_2696_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2005_1091_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_3250_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2008_2170_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2006_18_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_297_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2003_1997_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2006_32_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_1930_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_1537_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_775_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_1357_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2005_770_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2014_30_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2011_21_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2008_836_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_764_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_708_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_818_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2007_2478_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisr_2018_97_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_373_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisr_2017_190_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2005_1126_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_287_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2008_14_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_1349_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_513_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_1436_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_231_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_3004_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisr_2017_216_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2012_5_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_1907_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_2321_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2006_1963_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2006_569_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2023_20_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_1167_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_983_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_821_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_896_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2023_18_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2016_407_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_902_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2007_11_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_3094_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_402_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2007_2130_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_167_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_212_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_33_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_3226_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_634_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2007_5_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2007_289_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2004_2310_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_2581_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2017_16_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_52_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_886_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_606_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1293_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2003_1361_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_1148_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_282_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_1583_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2007_1093_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2007_1081_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2006_246_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2007_2194_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_924_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2010_15_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_3054_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2007_849_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2008_3137_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_101_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_1133_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisr_2019_7_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2005_1907_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_358_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2006_572_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_353_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2006_575_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2006_25_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_901_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_1037_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2005_2011_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_572_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisr_2017_44_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2005_22_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_1360_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_1341_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2014_19_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2022_4_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2005_3229_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_157_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_1182_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2014_28_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_578_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_1621_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2001_1123_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_58_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_1012_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_630_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_886_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_1283_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ssi_2021_174_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2016_1034_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2004_1360_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_1640_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisr_2018_138_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisr_2018_1_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2006_207_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisr_2025_176_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_234_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_1319_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2016_18_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_2888_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_1027_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_2796_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_209_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_2657_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2008_954_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2015_8_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ssi_2020_352_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2008_12_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2007_1388_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_859_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisr_2016_236_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_529_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_1544_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_1881_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2016_33_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_1583_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_1890_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_2846_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_1250_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_56_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_360_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2004_1945_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_1126_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_211_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_992_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nia_2015_5_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisi_2015_2006_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_2317_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_1511_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_2035_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_2430_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_1187_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_1755_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2016_1250_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2007_29_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_248_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_403_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_2279_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_2438_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2003_1652_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2005_7_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_45_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_338_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_1344_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_1171_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2006_1671_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_374_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_2461_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_308_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_346_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2007_3068_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2014_6_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2016_11_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukdsi_2017_9780111159194_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_wsi_2021_861_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2017_30_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_wsi_2018_342_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_351_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2023_28_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_1069_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_382_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_893_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1447_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_1431_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_1411_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_2568_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2011_4_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_614_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_3329_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_1886_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_2242_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_2576_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_2329_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_585_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_2037_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_3188_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_3218_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_3001_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1499_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_710_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_1313_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_348_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_1741_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_575_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_2880_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_1211_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_1283_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_1250_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_374_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_3227_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_2860_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_504_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_1009_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_239_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_1158_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2001_2_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_834_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_1961_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2004_3256_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2011_5_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1449_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_530_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_976_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_1298_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_675_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_2036_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_735_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_1108_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_1064_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_1028_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisr_2021_167_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_991_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_739_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_742_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ssi_2017_456_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_3323_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2016_7_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2015_26_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_161_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1301_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_1173_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_1285_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_433_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_113_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_739_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2018_10_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_1115_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_1297_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2016_680_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_1847_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2015_15_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2016_627_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_428_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_377_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2018_13_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_442_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_383_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_438_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_490_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_1660_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_1630_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_1424_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1535_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_1447_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_1043_data.xml
# ...
# [2] Fetching network data: http://www.legislation.gov.uk/nia/2016/21/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2014/11/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2021/28/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1995/428/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/1976/1041/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1995/248/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2017/37/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/1989/1342/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/1996/1705/data.xml
# Failed to fetch http://www.legislation.gov.uk/nisi/1996/1705/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/nisi/1996/1705/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2017/73/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1999/371/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2005/544/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/1977/2156/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2016/189/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/677/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2007/295/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2015/329/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1995/434/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2006/405/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2009/375/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1999/350/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nia/2009/3/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/1993/1579/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2008/291/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/2003/3202/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1994/17/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2006/478/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2001/3929/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/1991/2628/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2002/75/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2005/3255/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2023/145/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/1975/1504/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2025/67/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1999/481/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/2006/1947/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/285/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1997/192/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2000/246/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1999/310/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2000/374/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1995/405/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2023/30/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2008/147/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2000/332/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2005/6/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1996/401/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2003/273/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2009/216/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/1508/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1998/1506/data.xml
# Failed to fetch http://www.legislation.gov.uk/nisr/1998/1506/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/nisr/1998/1506/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/apni/1948/13/data.xml
# Failed to fetch http://www.legislation.gov.uk/apni/1948/13/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/apni/1948/13/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/apni/1966/35/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2016/220/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2008/399/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1992/560/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2003/396/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1995/110/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1997/1183/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2009/3/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1996/26/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2001/141/data.xml
# Failed to fetch http://www.legislation.gov.uk/uksi/2001/141/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/uksi/2001/141/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2013/2317/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/apni/1946/21/data.xml
# Failed to fetch http://www.legislation.gov.uk/apni/1946/21/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/apni/1946/21/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2025/337/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1994/427/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2001/114/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2023/181/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1995/2705/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2017/166/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2021/256/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2012/120/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2002/321/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/1983/1121/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2007/67/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2023/134/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/1976/582/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1995/293/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2019/77/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2001/260/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1987/82/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2003/204/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1995/69/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nia/2010/13/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/apni/1971/8/data.xml
# Failed to fetch http://www.legislation.gov.uk/apni/1971/8/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/apni/1971/8/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1998/395/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1999/407/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2015/1670/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1997/400/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2013/16/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/1996/2705/data.xml
# Failed to fetch http://www.legislation.gov.uk/nisi/1996/2705/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/nisi/1996/2705/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1999/102/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2019/23/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/apni/1950/7/data.xml
# Failed to fetch http://www.legislation.gov.uk/apni/1950/7/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/apni/1950/7/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/1994/766/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1996/51/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1995/477/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2023/45/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2002/408/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1943/39/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1999/663/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/1493/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2019/479/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2005/166/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1995/150/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2023/280/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2019/519/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2003/418/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2010/133/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2024/309/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/1990/1511/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/1993/592/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/2016/999/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1992/1725/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2016/228/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nia/2015/1/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2015/281/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2002/406/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1992/561/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2011/1484/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/2003/418/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2022/144/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/1996/1632/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/1574/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nia/2002/5/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2021/277/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1997/1577/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1994/262/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2016/234/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1992/328/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2008/413/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2001/141/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1974/47/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/302/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1996/297/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1996/492/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2009/90/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nia/2002/10/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/1995/2702/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1996/26/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1972/57/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1996/180/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/1980/346/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/1989/1339/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2012/9780111519189/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2020/9780348210132/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2016/9780111141991/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2003/0110449649/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2016/9780111141113/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2019/9780111178706/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2007/9780110758312/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2009/9780111473337/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2025/9780348267945/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/1999/011082105X/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2014/9780111121658/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2022/9780348233483/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2011/9780111506363/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2021/9780348219135/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2014/9780111121535/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2016/9780111143056/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2022/9780348240689/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2015/9780111127377/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2007/9780110758336/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2001/0110189248/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2018/9780111174074/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2004/0110491505/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2020/9780348215359/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2019/9780111176726/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2019/9780111176610/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2003/0110443446/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nidsr/2010/9780337980510/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2016/9780111148044/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2020/9780348212686/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukdsi/2015/9780111140604/data.xml
#
# Crawl complete. Processed 6448 unique pieces of legislation.
#
# Processing legislation: http://legislation.gov.uk/ukpga/2013/29
# [0] Loading from cache: .cache/legislation.gov.uk_ukpga_2013_29_data.xml
#
# Crawl complete. Processed 6449 unique pieces of legislation.
#
# Processing legislation: http://legislation.gov.uk/ukpga/2024/3
# [0] Loading from cache: .cache/legislation.gov.uk_ukpga_2024_3_data.xml
#
# Crawl complete. Processed 6450 unique pieces of legislation.
