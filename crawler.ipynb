# %%
# Load dotenv
from dotenv import load_dotenv
import os

load_dotenv()

LEGISLATION_URL_PREFIX = os.getenv('LEGISLATION_URL_PREFIX')
LEGISLATION_URI_LIST_FILE = os.getenv('LEGISLATION_URI_LIST_FILE')
JSON_OUTPUT_DIR = os.getenv('JSON_OUTPUT_DIR', 'json_out')
DEPTH_LIMIT = int(os.getenv('DEPTH_LIMIT', 2))

# %%
import os
import requests
from bs4 import BeautifulSoup
import json
from collections import deque

class LegislationCrawler:
    def __init__(self, max_depth=2):
        self.max_depth = max_depth
        self.visited_urls = set()
        # Queue stores tuples of: (url, current_depth)
        self.queue = deque() 
        
        # Ensure directories exist
        os.makedirs('.cache', exist_ok=True)
        os.makedirs(JSON_OUTPUT_DIR, exist_ok=True)

    def get_safe_filename(self, url):
        clean_url = url.split('://')[-1].replace(LEGISLATION_URL_PREFIX + '/', '')
        return clean_url.replace('/', '_')

    def normalize_url(self, uri):
        """
        Converts a citation URI (e.g., /id/ukpga/2025/8) into the actual 
        data XML endpoint (e.g., /ukpga/2025/8/data.xml).
        """
        if not uri:
            return None
        # Remove the '/id/' namespace often used in citation URIs
        clean_uri = uri.replace('/id/', '/')
        clean_uri = clean_uri.rstrip('/')
        if not clean_uri.endswith('data.xml'):
            return f"{clean_uri}/data.xml"
        return clean_uri

    def extract_identifier(self, soup):
        """
        Extracts the main identifier information from the XML soup.
        """
        identifier = {}
        title = soup.find('dc:title')
        identifier['title'] = title.text.strip() if title else None
        description = soup.find('dc:description')
        identifier['description'] = description.text.strip() if description else None
        publisher = soup.find('dc:publisher')
        identifier['publisher'] = publisher.text.strip() if publisher else None
        modified = soup.find('dc:modified')
        identifier['modified'] = modified.text.strip() if modified else None
        identifier_tag = soup.find('dc:identifier')
        identifier['uri'] = identifier_tag.text.strip() if identifier_tag else None
        valid = soup.find('dct:valid')
        identifier['valid_date'] = valid.text.strip() if valid else None
        return identifier
        
    def extract_primary_metadata(self, soup):
        """
        Extracts the primary metadata fields and unapplied effects from the XML soup.
        """
        metadata = {}
        primary_metadata = soup.find('ukm:PrimaryMetadata')
        if not primary_metadata: return metadata
            
        year = primary_metadata.find('ukm:Year')
        metadata['year'] = year.get('Value') if year else None
        number = primary_metadata.find('ukm:Number')
        metadata['number'] = number.get('Value') if number else None
        enactment = primary_metadata.find('ukm:EnactmentDate')
        metadata['enactment_date'] = enactment.get('Date') if enactment else None
        isbn = primary_metadata.find('ukm:ISBN')
        metadata['isbn'] = isbn.get('Value') if isbn else None
        
        unapplied_effects_list = []
        for effect in primary_metadata.find_all('ukm:UnappliedEffect'):
            effect_data = {
                "effect_id": effect.get('EffectId'),
                "type": effect.get('Type'), 
                "affected_provisions": effect.get('AffectedProvisions'),
                "affecting_provisions": effect.get('AffectingProvisions'),
                "requires_applied": effect.get('RequiresApplied') == 'true',
                "notes": effect.get('Notes'),
                "modified_date": effect.get('Modified'),
                "affecting_title": None,
                "in_force_date": None,
                "in_force_qualification": None
            }
            affecting_title = effect.find('ukm:AffectingTitle')
            if affecting_title: effect_data['affecting_title'] = affecting_title.text.strip()
            in_force = effect.find('ukm:InForce')
            if in_force:
                if in_force.get('Date'): effect_data['in_force_date'] = in_force.get('Date')
                elif in_force.get('Prospective') == 'true': effect_data['in_force_date'] = 'Prospective'
                effect_data['in_force_qualification'] = in_force.get('Qualification') or in_force.get('OtherQualification')
            unapplied_effects_list.append(effect_data)
            
        metadata['unapplied_effects'] = unapplied_effects_list
        return metadata

    def fetch_and_parse(self, target_url, current_depth):
        """Core parsing logic adapted for the class structure."""
        xml_url = self.normalize_url(target_url)
        if not xml_url: return None
        
        # Prevent duplicate processing (especially important for base URLs vs data.xml variations)
        base_identifying_url = xml_url.replace('/data.xml', '')
        if base_identifying_url in self.visited_urls:
            return None
            
        self.visited_urls.add(base_identifying_url)
        
        safe_name = self.get_safe_filename(xml_url)
        cache_filepath = os.path.join('.cache', safe_name)
        
        # Cache Check
        if os.path.exists(cache_filepath):
            print(f"[{current_depth}] Loading from cache: {cache_filepath}")
            with open(cache_filepath, 'rb') as f:
                xml_content = f.read()
        else:
            print(f"[{current_depth}] Fetching network data: {xml_url}")
            try:
                response = requests.get(xml_url)
                response.raise_for_status()
                xml_content = response.content
                # Before writing to cache, let's beautify the XML for consistent formatting
                temp_soup = BeautifulSoup(xml_content, 'xml')
                xml_content = temp_soup.prettify(encoding='utf-8')
                with open(cache_filepath, 'wb') as f:
                    f.write(xml_content)
            except requests.exceptions.RequestException as e:
                print(f"Failed to fetch {xml_url}: {e}")
                return None
            
        soup = BeautifulSoup(xml_content, 'xml')
        identifier = self.extract_identifier(soup)
        metadata = self.extract_primary_metadata(soup)
        
        # Dynamically create the filepath based on the extracted year
        doc_year = metadata.get('year') or "unknown_year"
        year_dir = os.path.join(JSON_OUTPUT_DIR, str(doc_year))
        os.makedirs(year_dir, exist_ok=True)
        json_filepath = os.path.join(year_dir, safe_name.replace('.xml', '.json'))
        
        commentaries_map = {}
        found_citations = set() # Track new citations to queue
        
        for comm in soup.find_all('Commentary'):
            comm_id = comm.get('id')
            if not comm_id: continue
                
            full_text = comm.get_text(separator=" ", strip=True)
            citations = []
            
            for cit in comm.find_all('Citation'):
                cit_uri = cit.get('URI')
                citations.append({
                    "id": cit.get('id'),
                    "uri": cit_uri,
                    "title": cit.get('Title'),
                    "class": cit.get('Class'),
                    "year": cit.get('Year'),
                    "number": cit.get('Number'),
                    "text": cit.text.strip()
                })
                # If we haven't hit max depth, prepare to queue this citation
                if cit_uri and current_depth < self.max_depth:
                    found_citations.add(cit_uri)
                
            citation_subrefs = []
            for subref in comm.find_all('CitationSubRef'):
                citation_subrefs.append({
                    "id": subref.get('id'),
                    "uri": subref.get('URI'),
                    "citation_ref": subref.get('CitationRef'), 
                    "section_ref": subref.get('SectionRef'),
                    "text": subref.text.strip()
                })
                
            commentaries_map[comm_id] = {
                "type": comm.get('Type'),
                "text": full_text,
                "citations": citations,
                "citation_subrefs": citation_subrefs
            }

        # Document Tree Building (main body)
        document_tree = {}
        
        # Filter: Only grab P1s that are NOT inside the <Schedules> block
        body_p1s = [p1 for p1 in soup.find_all('P1') if not p1.find_parent('Schedules')]
        
        for section in body_p1s:
            part = section.find_parent('Part')
            chapter = section.find_parent('Chapter')
            p1group = section.find_parent('P1group') 
            
            part_num = part.find('Number').text.strip() if part and part.find('Number') else "No Part"
            part_title = part.find('Title').text.strip() if part and part.find('Title') else None
            chapter_uri = chapter.get('DocumentURI') if chapter else None
            chapter_num = chapter.find('Number').text.strip() if chapter and chapter.find('Number') else "No Chapter"
            chapter_title = chapter.find('Title').text.strip() if chapter and chapter.find('Title') else None
            
            chap_dict_key = chapter_uri or chapter_num
            
            if part_num not in document_tree:
                document_tree[part_num] = {"title": part_title, "chapters": {}}
                
            if chap_dict_key not in document_tree[part_num]["chapters"]:
                document_tree[part_num]["chapters"][chap_dict_key] = {
                    "chapter_uri": chapter_uri,
                    "chapter_number": chapter_num if chapter_num != "No Chapter" else None,
                    "title": chapter_title, 
                    "sections": []
                }
                
            section_num = section.find('Pnumber').text.strip() if section.find('Pnumber') else None
            section_title = p1group.find('Title').text.strip() if p1group and p1group.find('Title') else None
            
            section_commentaries = []
            for cref in section.find_all('CommentaryRef'):
                if cref.find_parent('P2') is None:
                    ref_id = cref.get('Ref')
                    if ref_id in commentaries_map:
                        section_commentaries.append({"ref_id": ref_id, **commentaries_map[ref_id]})

            section_data = {
                "section_number": section_num,
                "title": section_title,
                "uri": section.get('DocumentURI') or section.get('id'),
                "commentaries": section_commentaries,
                "paragraphs": []
            }
            
            paragraphs = section.find_all('P2')
            if not paragraphs:
                text_nodes = section.find_all('Text')
                section_data["text"] = " ".join([t.get_text(separator=" ", strip=True) for t in text_nodes])
            else:
                for para in paragraphs:
                    para_num = para.find('Pnumber').text.strip() if para.find('Pnumber') else None
                    para_text = " ".join([t.get_text(separator=" ", strip=True) for t in para.find_all('Text')])
                    
                    para_commentaries = []
                    for cref in para.find_all('CommentaryRef'):
                        ref_id = cref.get('Ref')
                        if ref_id in commentaries_map:
                            para_commentaries.append({"ref_id": ref_id, **commentaries_map[ref_id]})
                    
                    section_data["paragraphs"].append({
                        "paragraph_number": para_num,
                        "text": para_text,
                        "uri": para.get('DocumentURI') or para.get('id'),
                        "commentaries": para_commentaries
                    })
            
            document_tree[part_num]["chapters"][chap_dict_key]["sections"].append(section_data)

        # Document Tree Building (schedules)
        schedules_list = []
        schedules_root = soup.find('Schedules')
        
        if schedules_root:
            for schedule in schedules_root.find_all('Schedule'):
                sched_num = schedule.find('Number').text.strip() if schedule.find('Number') else None
                # Get the first Title tag (handles both <TitleBlock><Title> and direct <Title>)
                sched_title_node = schedule.find('Title')
                sched_title = sched_title_node.get_text(strip=True) if sched_title_node else None
                sched_ref = schedule.find('Reference').text.strip() if schedule.find('Reference') else None
                
                sched_obj = {
                    "schedule_number": sched_num,
                    "title": sched_title,
                    "reference": sched_ref,
                    "uri": schedule.get('DocumentURI') or schedule.get('id'),
                    "paragraphs": []
                }
                
                # In schedules, <P1> represents a paragraph
                for p1 in schedule.find_all('P1'):
                    p1_num = p1.find('Pnumber').text.strip() if p1.find('Pnumber') else None
                    
                    # Check for an enclosing <Pblock> (crossheading title)
                    pblock = p1.find_parent('Pblock')
                    pblock_title = pblock.find('Title').get_text(strip=True) if pblock and pblock.find('Title') else None
                    
                    p1_commentaries = []
                    for cref in p1.find_all('CommentaryRef'):
                        if cref.find_parent('P2') is None:
                            ref_id = cref.get('Ref')
                            if ref_id in commentaries_map:
                                p1_commentaries.append({"ref_id": ref_id, **commentaries_map[ref_id]})
                                
                    p1_data = {
                        "paragraph_number": p1_num,
                        "crossheading": pblock_title,
                        "uri": p1.get('DocumentURI') or p1.get('id'),
                        "commentaries": p1_commentaries,
                        "subparagraphs": []
                    }
                    
                    # In schedules, <P2> represents a sub-paragraph
                    p2s = p1.find_all('P2')
                    if not p2s:
                        p1_data["text"] = " ".join([t.get_text(separator=" ", strip=True) for t in p1.find_all('Text')])
                    else:
                        for p2 in p2s:
                            p2_num = p2.find('Pnumber').text.strip() if p2.find('Pnumber') else None
                            p2_text = " ".join([t.get_text(separator=" ", strip=True) for t in p2.find_all('Text')])
                            
                            p2_commentaries = []
                            for cref in p2.find_all('CommentaryRef'):
                                ref_id = cref.get('Ref')
                                if ref_id in commentaries_map:
                                    p2_commentaries.append({"ref_id": ref_id, **commentaries_map[ref_id]})
                            
                            p1_data["subparagraphs"].append({
                                "subparagraph_number": p2_num,
                                "text": p2_text,
                                "uri": p2.get('DocumentURI') or p2.get('id'),
                                "commentaries": p2_commentaries
                            })
                            
                    sched_obj["paragraphs"].append(p1_data)
                    
                schedules_list.append(sched_obj)

        # Assemble Final JSON
        final_json_structure = {
            "legislation_url": identifier.get('uri'),
            "identifier": identifier,
            "metadata": metadata, 
            "parts": [],
            "schedules": schedules_list  # Newly injected root array
        }
        
        # Assembly loop
        for p_num, p_data in document_tree.items():
            part_obj = {
                "part_number": p_num if p_num != "No Part" else None, 
                "title": p_data["title"], 
                "chapters": []
            }
            
            for chap_key, c_data in p_data["chapters"].items():
                chapter_obj = {
                    "uri": c_data["chapter_uri"], 
                    "chapter_number": c_data["chapter_number"], 
                    "title": c_data["title"], 
                    "sections": c_data["sections"]
                }
                part_obj["chapters"].append(chapter_obj)
                
            final_json_structure["parts"].append(part_obj)

        with open(json_filepath, 'w', encoding='utf-8') as f:
            f.write(json.dumps(final_json_structure, indent=4))
            
        # Add the found citations to our queue for the next loop
        for cit_url in found_citations:
            # Check if we've already seen the base identifying URL
            normalized = self.normalize_url(cit_url)
            if normalized and normalized.replace('/data.xml', '') not in self.visited_urls:
                self.queue.append((cit_url, current_depth + 1))

    def crawl(self, start_url):
        """
        Starts the queue processor.
        """
        self.queue.append((start_url, 0)) # Start at depth 0
        
        while self.queue:
            current_url, depth = self.queue.popleft()
            self.fetch_and_parse(current_url, depth)
            
        print(f"\nCrawl complete. Processed {len(self.visited_urls)} unique pieces of legislation.")

# %%
crawler = LegislationCrawler(max_depth=DEPTH_LIMIT)

# Read LEGISLATION_URI_LIST_FILE and process each URI
with open(LEGISLATION_URI_LIST_FILE, 'r') as f:
    legislation_uris = [line.strip() for line in f if line.strip()]
for uri in legislation_uris:
    full_url = f"{LEGISLATION_URL_PREFIX}{uri}"
    print(f"\nProcessing legislation: {full_url}")
    crawler.crawl(full_url)
# Out:
# Processing legislation: https://www.legislation.gov.uk/ukpga/2020/14
# [0] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2020_14_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_740_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2021_26_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2023_30_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2022_3_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_500_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_1130_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_113_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_531_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_92_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2024_3_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_434_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1994_23_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_1417_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_874_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_799_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2023_1_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_1277_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2025_8_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_149_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_1409_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_399_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_1132_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_770_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_130_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_128_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_440_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_1278_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_589_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_884_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_96_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_918_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_522_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_1164_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_69_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_1321_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2017_32_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2024_12_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_569_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_1134_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_419_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_912_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_897_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_356_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_286_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_1012_data.xml
#
# Crawl complete. Processed 46 unique pieces of legislation.
#
# Processing legislation: https://www.legislation.gov.uk/ukpga/2010/4
# [0] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2010_4_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2013_2_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_734_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2020_12_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1998_36_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_1179_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2011_11_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_636_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_736_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2014_26_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_465_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_143_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_wsi_2018_101_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_2971_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_423_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ssi_2015_108_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2018_22_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_79_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_1388_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_628_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_1962_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2002_29_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2006_964_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_402_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_744_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1992_12_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_724_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1545_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_1087_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_1174_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2009_4_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_wsi_2018_34_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_asp_2013_11_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_689_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_1399_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_63_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_105_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2015_33_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2006_3296_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_818_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1642_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2020_1_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_1662_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2017_22_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_2999_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_1253_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_1072_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2007_3_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_952_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2010_36_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2010_8_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_700_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2016_898_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2022_40_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_464_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2012_21_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1495_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_1458_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_674_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_57_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2017_4_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_2902_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2010_13_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2010_33_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_964_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1981_63_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_463_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_518_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2019_1_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2003_1_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2003_14_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_245_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_2977_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2011_20_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_200_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2010_31_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_anaw_2017_1_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2015_21_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_1785_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2016_24_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2013_29_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2012_14_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_1078_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_3209_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_364_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_78_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2005_5_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_662_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_1271_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_725_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_1817_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_98_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2015_11_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_2595_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_716_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_266_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_1270_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_855_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2020_26_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_2885_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2023_53_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_1815_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2014_7_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_555_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2014_14_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_3327_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2010_4_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_685_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2014_21_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2018_3_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2011_25_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_518_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2017_10_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_286_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_1938_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_665_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_2819_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2011_24_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_2395_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2022_31_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2020_14_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_460_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_2228_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_3013_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1033_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisr_2021_258_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_229_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisr_2021_75_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_710_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_643_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisr_2020_211_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1349_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_856_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_744_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisr_2021_104_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_441_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ssi_2020_284_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisr_2022_4_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_60_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_375_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1031_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_1091_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ssi_2020_421_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisr_2021_259_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisr_2020_331_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2007_1050_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_571_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2005_22_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2001_9_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_404_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2001_1163_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2005_11_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2008_954_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_9_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1982_50_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1975_22_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1978_42_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1999_2975_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2005_3338_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisi_1986_1032_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1979_5_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1976_40_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2000_2319_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2007_11_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_2035_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2006_25_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1931_49_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1960_62_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1999_2908_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2005_3454_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1920_67_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1915_89_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_402_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_1022_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1985_6_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1998_3092_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1993_34_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1999_16_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1994_9_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2001_2_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2001_3629_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2008_2302_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_704_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1973_36_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1988_1_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_892_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1979_4_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1963_25_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2008_381_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1877_2_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1970_9_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1996_8_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2002_23_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1997_58_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1969_16_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2008_568_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2005_1126_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2000_17_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2008_9_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1968_2_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2007_2086_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_1037_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1978_30_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1992_40_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1990_1_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_405_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1891_39_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1988_39_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_403_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1980_48_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1975_7_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1999_619_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2009_10_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1984_51_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1979_7_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_apni_1963_22_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1998_2243_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_511_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1994_22_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1968_13_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_1890_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_56_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2006_3399_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2004_12_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1997_16_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1989_26_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1986_41_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1971_29_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2005_7_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2011_4_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_1307_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1891_38_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1983_56_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_2280_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2016_874_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_2459_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_3015_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2016_11_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2016_606_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_1740_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_834_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_1064_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_393_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_3062_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2016_22_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_607_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_2934_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2014_30_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2016_1212_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_1204_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_996_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_2880_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_692_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_3226_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_1183_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_1741_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_812_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ssi_2018_141_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_931_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_2461_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1992_4_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2015_5_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_1076_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_557_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_1248_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1435_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1629_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1641_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_914_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_983_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1438_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1439_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1643_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_1249_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_1362_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_108_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_855_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1449_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1312_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_561_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_97_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_513_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_1289_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_714_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_1258_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_12_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1434_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1457_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_450_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_104_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2020_29_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_385_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1622_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_487_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_113_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_1364_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_69_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1605_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_429_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1662_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_783_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_1489_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1432_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_819_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisi_1990_1504_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2012/318/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2012/318/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2012/318/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ssi_2008_393_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2007_2194_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_aep_1695_12_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1993_6_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_2160_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1986_1925_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_18_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1986_45_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2002_40_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2023_29_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1925_20_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_22_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2006_51_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1972_68_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2004_33_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_asp_2007_3_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2000_8_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ssi_2003_231_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1907_24_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2008_948_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2002_26_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_1613_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2001/400/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2001/400/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2001/400/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1999_1820_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2004/355/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2004/355/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2004/355/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2008/118/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2008/118/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2008/118/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2001_3816_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/1994/26/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/1994/26/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/1994/26/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2002_1240_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2007_2149_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1986_2268_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_208_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2004_27_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1985_66_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_1941_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2001_3649_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1995_7_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2003/355/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2003/355/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2003/355/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2003_21_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_1759_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2004_2738_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1986_60_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisi_2002_3152_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_1382_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_1641_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/1979/195/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/1979/195/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/1979/195/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisi_1989_2405_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2008_7_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_779_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1994_12_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1993_602_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2011/151/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2011/151/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2011/151/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisi_2005_1452_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_2866_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_514_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2003/549/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2003/549/data.xml: 400 Client Error: Bad Request for url: https://www.legislation.gov.uk/ukcm/2003/549/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/1991/364/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/1991/364/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/1991/364/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1987_1921_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2001_1062_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2001_1060_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1989_40_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1994_2421_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1975_1023_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2002/334/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2002/334/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2002/334/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2002_3203_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1988_36_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2000_39_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_400_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2006/47/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2006/47/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2006/47/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1998_46_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2002/261/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2002/261/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2002/261/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/1995/291/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/1995/291/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/1995/291/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2006_3429_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1963_18_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1986_1915_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2000/247/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2000/247/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2000/247/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2009/303/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2009/303/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2009/303/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1986_1996_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2001_544_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2009/404/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2009/404/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2009/404/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ssi_2013_50_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2008_1897_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_472_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1993_36_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisi_2005_1455_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nia_2008_13_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ssi_2013_119_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_470_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2003_333_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_82_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2002_3055_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2019_3_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2012_10_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2016_553_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_80_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_3098_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisr_2015_190_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_1640_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_asp_2002_17_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_1511_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_546_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_453_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ssi_2006_281_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2007_3287_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2020_9_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_wsi_2018_196_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nia_2014_11_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2015_9_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2008_949_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2003_32_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2003_173_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisr_2005_4_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2002_3133_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_317_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2005_3495_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2006_2406_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2005_3136_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_33_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ssi_2014_187_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_1432_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nia_2015_2_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2013_3_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2003_3103_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2007_3166_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2007_15_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ssi_2019_281_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2007_27_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_976_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisr_2009_22_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_625_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_838_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_112_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2005_2026_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ssi_2011_231_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ssi_2008_115_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1309_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_1320_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_1376_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2022_10_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1984_60_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2004_2066_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2009_25_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2006_1085_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_742_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2022_32_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_964_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2003_44_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisr_2008_510_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_wsi_2013_2861_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_798_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2015_30_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2006_2811_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1236_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_asp_2015_12_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_1534_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ssi_2009_67_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_2299_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2016_147_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_778_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_534_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_816_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2006_378_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2016_148_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_868_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2016_25_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_994_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_1682_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_1042_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_739_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_1028_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_812_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_983_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_80_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2008_755_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ssi_2008_152_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_45_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_820_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2003_3074_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisi_2004_702_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisi_2003_435_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2008_298_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_269_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2018_24_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_1103_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2023_20_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisr_2012_119_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2006_308_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisr_2015_194_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_991_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisi_1989_1341_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2003_120_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2005_4_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ssi_2016_128_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisr_2024_82_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_519_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2008_2504_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2015_20_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2004_11_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_41_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_1239_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2003_3258_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_1167_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2018_12_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2013_22_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2007_3398_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_1476_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2002_3145_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_606_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2007_2874_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ssi_2003_210_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_3019_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2006_18_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_1240_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2003_3312_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2006_52_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2008_28_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_792_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2016_2_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2005_15_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_2761_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2008_219_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2003_1_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_2622_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_1604_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisr_2015_193_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_1881_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_2701_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_99_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisr_2021_167_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_1272_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2005_910_data.xml
# ...
# [0] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2003_1_data.xml
#
# Crawl complete. Processed 2540 unique pieces of legislation.
#
# Processing legislation: https://www.legislation.gov.uk/ukpga/1998/1
# [0] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1998_1_data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1998/210/data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1998_30_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1990_6_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_1998_2004_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1974_28_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_wsi_2006_1338_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1980_44_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2007_935_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1992_13_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2006/51/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2001/1211/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ssi_2011_215_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1998_1729_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2001_10_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1998_2215_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2003/1115/article/3/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2001_1274_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_1309_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2006_47_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1999_987_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1992_37_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2003/1115/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_1725_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1983_40_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2001_1507_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2000_2559_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2006_40_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_anaw_2014_1_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_1942_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1996_57_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2008_10_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/wsi/2015/29/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2000_3230_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2001_654_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2003_1667_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_1226_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2000/2199/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2007_3611_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2005_397_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1962_12_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2002_808_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_3317_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1998_3237_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1994_40_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_wsi_2018_415_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2006_1660_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2002_2439_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1999/674/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2006_2895_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_anaw_2014_5_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2005_1833_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_1225_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_297_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2001_2237_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ssi_2005_419_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2004_8_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2006_1338_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2000_21_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2005_18_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2009_22_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_asp_2005_6_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1973_50_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2000/970/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2008/3204/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2002_2217_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/wsi/2018/191/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1973_16_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1997_365_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1998_1_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1992_817_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1994/2204/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1992_831_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1994_30_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1996_9_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1996_43_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_nisi_1986_594_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1984_35_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1998_1677_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1989_31_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1997_1960_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1985_53_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1988_23_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1991_48_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1981_56_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1998_24_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1997_47_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1992_43_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1994_2_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1985_61_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1992_61_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1987_43_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1991_2872_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1999_3209_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1984_37_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1992_33_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1978_31_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1997_42_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1973_17_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1988_49_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1996_1748_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1946_36_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1999_2000_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1982_49_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1995_42_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1987_32_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1988_16_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1995_34_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1998_749_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1991_6_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1982_38_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1985_24_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1992_15_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1996_15_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1982_2_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1992_28_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1998_47_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1979_18_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1979_34_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1995_31_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1986_49_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1980_39_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1991_23_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1999_26_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1994_1_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1983_41_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1989_38_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1985_47_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1991_196_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1987_33_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1981_43_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1986_48_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1992_1702_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1981_33_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1987_7_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1990_27_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1978_37_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1997_27_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1996_1298_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1991_3_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1991_65_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1993_1753_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1988_27_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1998_14_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1997_40_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1986_66_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1999_1547_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1997_46_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1992_31_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1988_45_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1982_34_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1992_29_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1977_1165_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1986_61_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1991_1538_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1984_48_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1995_1895_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1996_30_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1987_38_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1980_12_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1988_22_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1990_38_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1994_1772_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1990_7_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_apni_1921_2_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1982_31_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1997_56_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1988_19_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1993_3_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1994_31_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1989_24_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1998_23_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1985_4_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1999_30_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1996_1297_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_1990_1442_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1984_62_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1994_18_data.xml
#
# Crawl complete. Processed 2718 unique pieces of legislation.
#
# Processing legislation: https://www.legislation.gov.uk/ukpga/2025/1253
# [0] Fetching network data: https://www.legislation.gov.uk/ukpga/2025/1253/data.xml
# Failed to fetch https://www.legislation.gov.uk/ukpga/2025/1253/data.xml: 400 Client Error: Bad Request for url: https://www.legislation.gov.uk/ukpga/2025/1253/data.xml
#
# Crawl complete. Processed 2719 unique pieces of legislation.
#
# Processing legislation: https://www.legislation.gov.uk/ukpga/2025/172
# [0] Fetching network data: https://www.legislation.gov.uk/ukpga/2025/172/data.xml
# Failed to fetch https://www.legislation.gov.uk/ukpga/2025/172/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukpga/2025/172/data.xml
#
# Crawl complete. Processed 2720 unique pieces of legislation.
#
# Processing legislation: https://www.legislation.gov.uk/ukpga/2023/221
# [0] Fetching network data: https://www.legislation.gov.uk/ukpga/2023/221/data.xml
# Failed to fetch https://www.legislation.gov.uk/ukpga/2023/221/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukpga/2023/221/data.xml
#
# Crawl complete. Processed 2721 unique pieces of legislation.
#
# Processing legislation: https://www.legislation.gov.uk/ukpga/2022/1203
# [0] Fetching network data: https://www.legislation.gov.uk/ukpga/2022/1203/data.xml
# Failed to fetch https://www.legislation.gov.uk/ukpga/2022/1203/data.xml: 400 Client Error: Bad Request for url: https://www.legislation.gov.uk/ukpga/2022/1203/data.xml
#
# Crawl complete. Processed 2722 unique pieces of legislation.
#
# Processing legislation: https://www.legislation.gov.uk/ukpga/2022/572
# [0] Fetching network data: https://www.legislation.gov.uk/ukpga/2022/572/data.xml
# Failed to fetch https://www.legislation.gov.uk/ukpga/2022/572/data.xml: 400 Client Error: Bad Request for url: https://www.legislation.gov.uk/ukpga/2022/572/data.xml
#
# Crawl complete. Processed 2723 unique pieces of legislation.
