# %%
# Load dotenv
from dotenv import load_dotenv
import os

load_dotenv()

LEGISLATION_URL_PREFIX = os.getenv('LEGISLATION_URL_PREFIX')
LEGISLATION_URI_LIST_FILE = os.getenv('LEGISLATION_URI_LIST_FILE')
JSON_OUTPUT_DIR = os.getenv('JSON_OUTPUT_DIR', 'json_out')

# %%
import os
import requests
from bs4 import BeautifulSoup
import json
from collections import deque

class LegislationCrawler:
    def __init__(self, max_depth=2):
        self.max_depth = max_depth
        self.visited_urls = set()
        # Queue stores tuples of: (url, current_depth)
        self.queue = deque() 
        
        # Ensure directories exist
        os.makedirs('.cache', exist_ok=True)
        os.makedirs(JSON_OUTPUT_DIR, exist_ok=True)

    def get_safe_filename(self, url):
        clean_url = url.split('://')[-1].replace(LEGISLATION_URL_PREFIX + '/', '')
        return clean_url.replace('/', '_')

    def normalize_url(self, uri):
        """
        Converts a citation URI (e.g., /id/ukpga/2025/8) into the actual 
        data XML endpoint (e.g., /ukpga/2025/8/data.xml).
        """
        if not uri:
            return None
        # Remove the '/id/' namespace often used in citation URIs
        clean_uri = uri.replace('/id/', '/')
        clean_uri = clean_uri.rstrip('/')
        if not clean_uri.endswith('data.xml'):
            return f"{clean_uri}/data.xml"
        return clean_uri

    def extract_identifier(self, soup):
        """
        Extracts the main identifier information from the XML soup.
        """
        identifier = {}
        title = soup.find('dc:title')
        identifier['title'] = title.text.strip() if title else None
        description = soup.find('dc:description')
        identifier['description'] = description.text.strip() if description else None
        publisher = soup.find('dc:publisher')
        identifier['publisher'] = publisher.text.strip() if publisher else None
        modified = soup.find('dc:modified')
        identifier['modified'] = modified.text.strip() if modified else None
        identifier_tag = soup.find('dc:identifier')
        identifier['uri'] = identifier_tag.text.strip() if identifier_tag else None
        valid = soup.find('dct:valid')
        identifier['valid_date'] = valid.text.strip() if valid else None
        return identifier
        
    def extract_primary_metadata(self, soup):
        """
        Extracts the primary metadata fields and unapplied effects from the XML soup.
        """
        metadata = {}
        primary_metadata = soup.find('ukm:PrimaryMetadata')
        if not primary_metadata: return metadata
            
        year = primary_metadata.find('ukm:Year')
        metadata['year'] = year.get('Value') if year else None
        number = primary_metadata.find('ukm:Number')
        metadata['number'] = number.get('Value') if number else None
        enactment = primary_metadata.find('ukm:EnactmentDate')
        metadata['enactment_date'] = enactment.get('Date') if enactment else None
        isbn = primary_metadata.find('ukm:ISBN')
        metadata['isbn'] = isbn.get('Value') if isbn else None
        
        unapplied_effects_list = []
        for effect in primary_metadata.find_all('ukm:UnappliedEffect'):
            effect_data = {
                "effect_id": effect.get('EffectId'),
                "type": effect.get('Type'), 
                "affected_provisions": effect.get('AffectedProvisions'),
                "affecting_provisions": effect.get('AffectingProvisions'),
                "requires_applied": effect.get('RequiresApplied') == 'true',
                "notes": effect.get('Notes'),
                "modified_date": effect.get('Modified'),
                "affecting_title": None,
                "in_force_date": None,
                "in_force_qualification": None
            }
            affecting_title = effect.find('ukm:AffectingTitle')
            if affecting_title: effect_data['affecting_title'] = affecting_title.text.strip()
            in_force = effect.find('ukm:InForce')
            if in_force:
                if in_force.get('Date'): effect_data['in_force_date'] = in_force.get('Date')
                elif in_force.get('Prospective') == 'true': effect_data['in_force_date'] = 'Prospective'
                effect_data['in_force_qualification'] = in_force.get('Qualification') or in_force.get('OtherQualification')
            unapplied_effects_list.append(effect_data)
            
        metadata['unapplied_effects'] = unapplied_effects_list
        return metadata

    def fetch_and_parse(self, target_url, current_depth):
        """Core parsing logic adapted for the class structure."""
        xml_url = self.normalize_url(target_url)
        if not xml_url: return None
        
        # Prevent duplicate processing (especially important for base URLs vs data.xml variations)
        base_identifying_url = xml_url.replace('/data.xml', '')
        if base_identifying_url in self.visited_urls:
            return None
            
        self.visited_urls.add(base_identifying_url)
        
        safe_name = self.get_safe_filename(xml_url)
        cache_filepath = os.path.join('.cache', safe_name)
        json_filepath = os.path.join(JSON_OUTPUT_DIR, safe_name.replace('.xml', '.json'))
        
        # Cache Check
        if os.path.exists(cache_filepath):
            print(f"[{current_depth}] Loading from cache: {cache_filepath}")
            with open(cache_filepath, 'rb') as f:
                xml_content = f.read()
        else:
            print(f"[{current_depth}] Fetching network data: {xml_url}")
            try:
                response = requests.get(xml_url)
                response.raise_for_status()
                xml_content = response.content
                with open(cache_filepath, 'wb') as f:
                    f.write(xml_content)
            except requests.exceptions.RequestException as e:
                print(f"Failed to fetch {xml_url}: {e}")
                return None
            
        soup = BeautifulSoup(xml_content, 'xml')
        identifier = self.extract_identifier(soup)
        metadata = self.extract_primary_metadata(soup)
        
        commentaries_map = {}
        found_citations = set() # Track new citations to queue
        
        for comm in soup.find_all('Commentary'):
            comm_id = comm.get('id')
            if not comm_id: continue
                
            full_text = comm.get_text(separator=" ", strip=True)
            citations = []
            
            for cit in comm.find_all('Citation'):
                cit_uri = cit.get('URI')
                citations.append({
                    "id": cit.get('id'),
                    "uri": cit_uri,
                    "title": cit.get('Title'),
                    "class": cit.get('Class'),
                    "year": cit.get('Year'),
                    "number": cit.get('Number'),
                    "text": cit.text.strip()
                })
                # If we haven't hit max depth, prepare to queue this citation
                if cit_uri and current_depth < self.max_depth:
                    found_citations.add(cit_uri)
                
            citation_subrefs = []
            for subref in comm.find_all('CitationSubRef'):
                citation_subrefs.append({
                    "id": subref.get('id'),
                    "uri": subref.get('URI'),
                    "citation_ref": subref.get('CitationRef'), 
                    "section_ref": subref.get('SectionRef'),
                    "text": subref.text.strip()
                })
                
            commentaries_map[comm_id] = {
                "type": comm.get('Type'),
                "text": full_text,
                "citations": citations,
                "citation_subrefs": citation_subrefs
            }

        # Document Tree Building
        document_tree = {}
        sections = soup.find_all('P1')
        
        for section in sections:
            part = section.find_parent('Part')
            chapter = section.find_parent('Chapter')
            p1group = section.find_parent('P1group') 
            
            part_num = part.find('Number').text.strip() if part and part.find('Number') else "No Part"
            part_title = part.find('Title').text.strip() if part and part.find('Title') else None
            chapter_num = chapter.find('Number').text.strip() if chapter and chapter.find('Number') else "No Chapter"
            chapter_title = chapter.find('Title').text.strip() if chapter and chapter.find('Title') else None
            
            if part_num not in document_tree:
                document_tree[part_num] = {"title": part_title, "chapters": {}}
            if chapter_num not in document_tree[part_num]["chapters"]:
                document_tree[part_num]["chapters"][chapter_num] = {"title": chapter_title, "sections": []}
                
            section_num = section.find('Pnumber').text.strip() if section.find('Pnumber') else None
            section_title = p1group.find('Title').text.strip() if p1group and p1group.find('Title') else None
            
            section_commentaries = []
            for cref in section.find_all('CommentaryRef'):
                if cref.find_parent('P2') is None:
                    ref_id = cref.get('Ref')
                    if ref_id in commentaries_map:
                        section_commentaries.append({"ref_id": ref_id, **commentaries_map[ref_id]})

            section_data = {
                "section_number": section_num,
                "title": section_title,
                "uri": section.get('DocumentURI') or section.get('id'),
                "commentaries": section_commentaries,
                "paragraphs": []
            }
            
            paragraphs = section.find_all('P2')
            if not paragraphs:
                text_nodes = section.find_all('Text')
                section_data["text"] = " ".join([t.get_text(separator=" ", strip=True) for t in text_nodes])
            else:
                for para in paragraphs:
                    para_num = para.find('Pnumber').text.strip() if para.find('Pnumber') else None
                    para_text = " ".join([t.get_text(separator=" ", strip=True) for t in para.find_all('Text')])
                    
                    para_commentaries = []
                    for cref in para.find_all('CommentaryRef'):
                        ref_id = cref.get('Ref')
                        if ref_id in commentaries_map:
                            para_commentaries.append({"ref_id": ref_id, **commentaries_map[ref_id]})
                    
                    section_data["paragraphs"].append({
                        "paragraph_number": para_num,
                        "text": para_text,
                        "uri": para.get('DocumentURI') or para.get('id'),
                        "commentaries": para_commentaries
                    })
                    
            document_tree[part_num]["chapters"][chapter_num]["sections"].append(section_data)

        # Assemble Final JSON
        final_json_structure = {
            "legislation_url": xml_url,
            "identifier": identifier,
            "metadata": metadata, 
            "parts": []
        }
        
        for p_num, p_data in document_tree.items():
            part_obj = {"part_number": p_num if p_num != "No Part" else None, "title": p_data["title"], "chapters": []}
            for c_num, c_data in p_data["chapters"].items():
                chapter_obj = {"chapter_number": c_num if c_num != "No Chapter" else None, "title": c_data["title"], "sections": c_data["sections"]}
                part_obj["chapters"].append(chapter_obj)
            final_json_structure["parts"].append(part_obj)

        with open(json_filepath, 'w', encoding='utf-8') as f:
            f.write(json.dumps(final_json_structure, indent=4))
            
        # Add the found citations to our queue for the next loop
        for cit_url in found_citations:
            # Check if we've already seen the base identifying URL
            normalized = self.normalize_url(cit_url)
            if normalized and normalized.replace('/data.xml', '') not in self.visited_urls:
                self.queue.append((cit_url, current_depth + 1))

    def crawl(self, start_url):
        """
        Starts the queue processor.
        """
        self.queue.append((start_url, 0)) # Start at depth 0
        
        while self.queue:
            current_url, depth = self.queue.popleft()
            self.fetch_and_parse(current_url, depth)
            
        print(f"\nCrawl complete. Processed {len(self.visited_urls)} unique pieces of legislation.")

# %%
crawler = LegislationCrawler(max_depth=2)

# Read LEGISLATION_URI_LIST_FILE and process each URI
with open(LEGISLATION_URI_LIST_FILE, 'r') as f:
    legislation_uris = [line.strip() for line in f if line.strip()]
for uri in legislation_uris:
    full_url = f"{LEGISLATION_URL_PREFIX}{uri}"
    print(f"\nProcessing legislation: {full_url}")
    crawler.crawl(full_url)
# Out:
# Processing legislation: https://www.legislation.gov.uk/ukpga/2010/4
# [0] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2010_4_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_245_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_964_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_2977_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2013_2_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_665_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_3209_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_465_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2015_33_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2023_30_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_1815_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_105_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2014_21_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_57_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_1662_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_1388_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2022_3_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_662_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_674_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_518_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2016_898_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_1458_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1545_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_463_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1495_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_wsi_2018_101_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_asp_2013_11_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2020_1_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_1087_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2006_964_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2006_3296_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_wsi_2018_34_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1981_63_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_286_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2017_4_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_734_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2010_31_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2007_3_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2015_21_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2010_2902_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1994_23_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2025_8_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2003_1_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_1399_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_2228_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2010_4_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2020_14_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2022_31_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_anaw_2017_1_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_1072_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2005_5_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2011_11_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_423_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_518_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_3327_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_952_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2009_4_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2015_11_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_818_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_364_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_200_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_79_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_402_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2020_12_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2017_32_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2020_26_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2014_14_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_685_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_2395_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2011_24_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_1938_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2014_26_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2003_14_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2017_22_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_716_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2022_40_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2002_29_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2024_3_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ssi_2015_108_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2018_22_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2012_14_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_2999_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_1271_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_78_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2012_21_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_1817_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_636_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_266_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_1642_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_2819_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_1253_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_286_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_700_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_1321_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_628_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_1962_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_464_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2014_7_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_2885_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2016_24_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_98_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2010_33_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_1179_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_2971_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2023_53_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2019_1_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_744_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2021_26_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1998_36_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_855_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2010_36_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2011_25_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_1078_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_1992_12_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_689_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_1270_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_1174_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2018_3_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_555_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_2595_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2021_724_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2013_29_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2011_20_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2017_10_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_460_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_1785_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_143_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2010_8_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2015_725_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_736_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_63_data.xml
# [1] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2010_13_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2001/3649/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2008/1897/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ssi/2005/125/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1986/1925/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/1301/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2018/1244/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1993/36/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1993/48/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2003/358/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2003/358/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2003/358/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2004/35/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2006/25/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2005/9/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/354/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1980/43/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2009/1208/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2004/593/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2014/3160/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1986/1960/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/asp/2002/17/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2015/17/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/1991/443/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/1991/443/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/1991/443/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2004/307/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2004/307/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2004/307/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2025/201/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2013/33/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2017/400/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2000/17/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2002/3150/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2008/948/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1970/9/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/1990/1504/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2005/1455/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2003/1417/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_1064_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2003/21/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1993/6/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1990/1504/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2006/54/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2006/54/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2006/54/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2009/2101/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1995/40/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2002/40/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1999/2979/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/1986/1032/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/1986/1032/data.xml: 400 Client Error: Bad Request for url: https://www.legislation.gov.uk/ukcm/1986/1032/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2013/1765/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1985/6/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1995/26/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/2005/255/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/asp/2001/13/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2006/46/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/1996/1919/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2013/472/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/1987/30/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/1987/30/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/1987/30/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1999/2975/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1996/1469/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2002/378/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2002/378/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2002/378/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2003/39/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisr/2023/157/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1996/1910/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1996/18/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2008/31/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/asp/2000/4/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/2002/3150/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2017/752/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2007/2194/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2005/1516/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2002/2822/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1994/3200/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2004/33/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2001/17/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2003/2096/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2007/832/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2008_9_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/1996/252/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/1996/252/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/1996/252/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/1975/1503/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2006/2975/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2009/1941/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1993/49/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2005/1986/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2010/28/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ssi/2005/465/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2001/967/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2006/50/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2008/1911/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1986/952/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2003/3363/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/1995/3213/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1994/12/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2000/8/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1986/2001/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1996/1909/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1989/2404/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2019/662/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2001/3755/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2005/916/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2003/3226/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_504_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2003/357/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2003/357/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2003/357/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/1991/364/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/1991/364/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/1991/364/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/1989/2405/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/1984/2796/data.xml
# Failed to fetch http://www.legislation.gov.uk/nisi/1984/2796/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/nisi/1984/2796/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_710_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2008/7/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/1995/225/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/1995/225/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/1995/225/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1992/1315/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2010/1056/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1995/43/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1994/2421/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1998/1870/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1986/41/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2018/208/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2000/39/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1994/2507/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2004/1822/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1989/15/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1973/52/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1987/2023/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2002/1240/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2009/3081/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2009/853/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2004/1045/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2007/2974/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2015/989/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1972/68/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2007_15_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2000/27/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1988/33/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1995/45/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/1991/301/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/1991/301/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/1991/301/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2019/348/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2005/4/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1986/45/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2005/126/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2005/126/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2005/126/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2019/680/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2007/3494/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1986/1915/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1986/2123/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1999/23/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2006/33/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2006/33/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2006/33/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/1981/1675/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2017/443/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1986/46/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2005/590/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1989/40/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2009/1/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1986/1996/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2008/1748/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2001/1090/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2008/346/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/asp/2007/3/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2005/524/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2009/214/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1987/18/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/2005/1455/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2010/18/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ssi/2006/485/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2004/27/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2009_10_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1991/880/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1986/1764/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2000/11/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2023/884/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2023/918/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2024/522/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2025/96/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1996/8/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2006_25_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_571_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/1641/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ssi/2016/48/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2017/462/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2015/1469/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ssi/2015/360/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/wsi/2017/1288/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2022/500/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2016/1007/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2015/1902/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2014/1823/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2015/773/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2019/558/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2023/1424/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/anaw/2016/3/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2017/58/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2016_465_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/wsi/2015/1786/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2018/397/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2017/926/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2014/3320/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2021/30/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2015/1641/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/2005/1452/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ssi/2013/50/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1987/1921/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2008/118/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2008/118/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2008/118/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2023/1382/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2001/1060/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2001/1062/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/aep/1695/12/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2006/3429/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2006/51/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2001/3816/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1995/7/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1993/602/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2011/151/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2011/151/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2011/151/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2007/2149/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1988/36/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/1979/195/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/1979/195/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/1979/195/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2001/544/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2004/2738/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2011/1613/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1986/60/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2002/334/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2002/334/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2002/334/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1925/20/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1999/1820/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ssi/2008/393/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2003/355/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2003/355/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2003/355/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/1995/291/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/1995/291/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/1995/291/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/1994/26/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/1994/26/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/1994/26/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2006/47/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2006/47/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2006/47/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2001/400/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2001/400/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2001/400/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2012/318/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2012/318/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2012/318/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1986/2268/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2012/1759/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1998/46/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2003/549/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2003/549/data.xml: 400 Client Error: Bad Request for url: https://www.legislation.gov.uk/ukcm/2003/549/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2023/779/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2009/303/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2009/303/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2009/303/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2011/2866/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2000/247/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2000/247/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2000/247/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2017/514/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/2002/3152/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2010/22/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2023/29/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1963/18/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1985/66/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1907/24/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2004/355/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2004/355/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2004/355/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2009/404/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2009/404/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2009/404/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2009/2160/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukcm/2002/261/data.xml
# Failed to fetch http://www.legislation.gov.uk/ukcm/2002/261/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/ukcm/2002/261/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2002/26/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2002/3203/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ssi/2003/231/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1975/1023/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_1164_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2022/569/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2023/69/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2024_12_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2024/869/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2003/3220/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2019/1215/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1999/16/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2007/1418/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1984/746/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2018/1248/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2005/2114/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_1043_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2019/486/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2019/175/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2018/1249/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2002/1142/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1988/809/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2012/2953/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2000/794/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1992/3130/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2019/108/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2019/60/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1996/1255/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2002/23/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1992/3122/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1999/3121/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1987/2108/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1995/2518/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2006/3157/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2010/2925/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2019/408/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1995/281/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2001/574/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1995/4/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/1544/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2014/1458/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2018/1328/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1992/3111/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2009/215/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2009/730/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2004/3140/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2005/762/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1997/1616/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2019/513/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2012/295/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1995/1269/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2010/2923/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2006/2187/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2013/701/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2019/91/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1992/3132/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1993/2001/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2018/1376/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1995/1268/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2015/1978/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2004/3148/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2019/59/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2009/3241/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1992/3156/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/1546/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1992/3222/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1996/1250/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2003/1114/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2002/1935/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1995/291/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2000/258/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/1412/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/1431/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2019/1214/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2009/1967/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2005/2231/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1995/958/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1995/3147/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1992/3193/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2019/104/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2021/1444/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_1298_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_1278_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1997/1086/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2019/1507/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2007_11_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2014/2430/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2018/1362/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2017/290/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2005/11/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/1088/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1997/16/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2019/1221/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2017/778/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2018/16/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ssi/2014/279/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/asp/2024/14/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ssi/2015/93/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/asp/2014/16/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ssi/2024/104/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ssi/2023/280/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ssi/2025/158/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_283_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ssi/2018/222/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ssi/2014/278/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ssi/2015/110/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/asp/2018/11/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ssi/2014/375/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ssi_2014_377_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ssi/2014/370/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ssi/2025/79/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/asp/2020/10/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2020_11_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/asp/2016/11/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ssi/2014/351/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ssi/2017/233/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ssi/2015/123/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ssi/2024/367/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ssi/2018/221/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/90/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2024/164/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ssi/2020/18/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2020/2/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2023/28/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/463/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/87/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/61/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/91/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2022/357/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/75/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/56/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/317/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/1622/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/93/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/104/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/518/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1997/1154/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2017/1227/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1989/26/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2008/3159/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2004/6/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_2036_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2013/1400/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2010/294/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2005_22_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2015/616/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2005_7_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2005/646/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1997/1715/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2001/3629/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2007/794/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2008/705/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2008/1463/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2012/1783/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2012/3043/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2009_56_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2012/519/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2013/2994/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2003/1831/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1970/24/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2002/1973/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2013/1772/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2011/244/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1987/51/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2004/2201/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2004_12_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2014/1932/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2015/485/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1992/48/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2011/2192/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2010/1642/data.xml
# ...
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2019/573/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2010/32/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2004/2575/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2001/1149/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1939/117/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1999/20/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2000/26/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2007/3546/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/wsi/2019/772/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1979/14/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1999/161/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2004/2744/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1995/3220/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2006/3271/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1992/1874/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1994/3228/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1999/29/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1994/2189/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1984/43/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1972/52/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1925/18/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2008/1579/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1998/3177/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1992/44/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1927/41/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1994/26/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1995/37/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2012/3044/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1997/41/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1964/28/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2007/3402/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1999/498/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2007/3186/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2002/1970/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1995/171/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1996/846/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2006/3291/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1994/728/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1989/469/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1998/1869/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2014/605/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2006/959/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/1994/2809/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2000/3316/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2021/213/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2011/701/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1972/65/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2005/1444/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1991/31/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2005/409/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2007/2134/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2022/230/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1993/236/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1986/56/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1986/387/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1982/53/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1997/473/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2005/2014/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/1981/156/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2005/1909/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1990/8/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1996/55/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2010/2901/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2004/36/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2008/3002/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1965/25/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1992/3066/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1998/17/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1968/59/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2012/1868/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1994/21/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1962/46/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1983/28/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1999/3434/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2005/14/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2000/12/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1996/2325/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2001/57/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1964/29/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/apni/1964/28/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1970/10/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1992/415/data.xml
# Failed to fetch http://www.legislation.gov.uk/uksi/1992/415/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/uksi/1992/415/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1993/37/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1998/2244/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1997/991/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1978/18/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2004/2199/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1994/2550/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2015/1540/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2008/2358/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2004/2200/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1999/564/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2000/38/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1964/56/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1992/1655/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1920/18/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2007/17/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2007/2145/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2004/20/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/nisi/1979/1573/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2003/23/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1972/40/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1986/53/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1981/35/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/315/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2000/2957/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1947/30/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/1994/3226/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/1985/69/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2019/1160/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2025/1330/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2017/1090/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2017/126/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2022_331_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2012/2029/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_639_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_3184_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_wsi_2022_98_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2013/1124/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_722_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_930_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_806_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_2931_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2018/1128/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_wsi_2014_2830_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2017/3/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_1714_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_118_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2021/1349/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_452_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_1463_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_wsi_2012_193_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_wsi_2021_1349_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_2734_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2016_449_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_863_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2016_653_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2017/399/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_103_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_649_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2019_957_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2025/86/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_2599_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_251_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_2754_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2014/2590/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2023_1001_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_wsi_2012_887_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2025/115/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_640_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2013_27_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2017/250/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_232_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2020/426/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2016_733_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2016_1_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukla_2013_6_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/ukpga/2014/12/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_2421_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2011_2896_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2023_36_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_1296_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2020_156_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2013_797_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_113_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_1133_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2018/648/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/anaw/2015/6/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_430_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2014/949/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_1008_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2025_1370_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2018_227_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2014_864_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2025_34_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2012/2420/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2014/865/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2025/117/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2024_402_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2017/612/data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2009_20_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_2913_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_wsi_2021_231_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2017_510_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_411_data.xml
# [2] Loading from cache: .cache/www.legislation.gov.uk_uksi_2012_696_data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2018/32/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2018/467/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2012/3041/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2014/3237/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2010/2938/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2010/3019/data.xml
# [2] Fetching network data: http://www.legislation.gov.uk/uksi/2011/975/data.xml
#
# Crawl complete. Processed 1951 unique pieces of legislation.
#
# Processing legislation: https://www.legislation.gov.uk/ukpga/2009/4
# [0] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2009_4_data.xml
#
# Crawl complete. Processed 1952 unique pieces of legislation.
#
# Processing legislation: https://www.legislation.gov.uk/ukpga/2003/14
# [0] Loading from cache: .cache/www.legislation.gov.uk_ukpga_2003_14_data.xml
#
# Crawl complete. Processed 1953 unique pieces of legislation.
