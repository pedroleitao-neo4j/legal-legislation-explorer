# %%
# Load dotenv
from dotenv import load_dotenv
import os

load_dotenv()

LEGISLATION_URL_PREFIX = os.getenv('LEGISLATION_URL_PREFIX')
LEGISLATION_URI_LIST_FILE = os.getenv('LEGISLATION_URI_LIST_FILE')
JSON_OUTPUT_DIR = os.getenv('JSON_OUTPUT_DIR', 'json_out')
DEPTH_LIMIT = int(os.getenv('DEPTH_LIMIT', 2))

# %%
import os
import requests
from bs4 import BeautifulSoup
import json
from collections import deque

class LegislationCrawler:
    def __init__(self, max_depth=2):
        self.max_depth = max_depth
        self.visited_urls = set()
        # Queue stores tuples of: (url, current_depth)
        self.queue = deque() 
        
        # Ensure directories exist
        os.makedirs('.cache', exist_ok=True)
        os.makedirs(JSON_OUTPUT_DIR, exist_ok=True)

    def get_safe_filename(self, url):
        clean_url = url.split('://')[-1].replace(LEGISLATION_URL_PREFIX + '/', '')
        return clean_url.replace('/', '_')

    def normalize_url(self, uri):
        """
        Converts a citation URI (e.g., /id/ukpga/2025/8) into the actual 
        data XML endpoint (e.g., /ukpga/2025/8/data.xml).
        """
        if not uri:
            return None
        # Remove the '/id/' namespace often used in citation URIs
        clean_uri = uri.replace('/id/', '/')
        clean_uri = clean_uri.rstrip('/')
        if not clean_uri.endswith('data.xml'):
            return f"{clean_uri}/data.xml"
        return clean_uri

    def extract_identifier(self, soup):
        """
        Extracts the main identifier information from the XML soup.
        """
        identifier = {}
        title = soup.find('dc:title')
        identifier['title'] = title.text.strip() if title else None
        description = soup.find('dc:description')
        identifier['description'] = description.text.strip() if description else None
        publisher = soup.find('dc:publisher')
        identifier['publisher'] = publisher.text.strip() if publisher else None
        modified = soup.find('dc:modified')
        identifier['modified'] = modified.text.strip() if modified else None
        identifier_tag = soup.find('dc:identifier')
        identifier['uri'] = identifier_tag.text.strip() if identifier_tag else None
        valid = soup.find('dct:valid')
        identifier['valid_date'] = valid.text.strip() if valid else None
        return identifier
        
    def extract_primary_metadata(self, soup):
        """
        Extracts the primary metadata fields and unapplied effects from the XML soup.
        """
        metadata = {}
        primary_metadata = soup.find('ukm:PrimaryMetadata')
        if not primary_metadata: return metadata
            
        year = primary_metadata.find('ukm:Year')
        metadata['year'] = year.get('Value') if year else None
        number = primary_metadata.find('ukm:Number')
        metadata['number'] = number.get('Value') if number else None
        enactment = primary_metadata.find('ukm:EnactmentDate')
        metadata['enactment_date'] = enactment.get('Date') if enactment else None
        isbn = primary_metadata.find('ukm:ISBN')
        metadata['isbn'] = isbn.get('Value') if isbn else None
        
        unapplied_effects_list = []
        for effect in primary_metadata.find_all('ukm:UnappliedEffect'):
            effect_data = {
                "effect_id": effect.get('EffectId'),
                "type": effect.get('Type'), 
                "affected_provisions": effect.get('AffectedProvisions'),
                "affecting_provisions": effect.get('AffectingProvisions'),
                "requires_applied": effect.get('RequiresApplied') == 'true',
                "notes": effect.get('Notes'),
                "modified_date": effect.get('Modified'),
                "affecting_title": None,
                "in_force_date": None,
                "in_force_qualification": None
            }
            affecting_title = effect.find('ukm:AffectingTitle')
            if affecting_title: effect_data['affecting_title'] = affecting_title.text.strip()
            in_force = effect.find('ukm:InForce')
            if in_force:
                if in_force.get('Date'): effect_data['in_force_date'] = in_force.get('Date')
                elif in_force.get('Prospective') == 'true': effect_data['in_force_date'] = 'Prospective'
                effect_data['in_force_qualification'] = in_force.get('Qualification') or in_force.get('OtherQualification')
            unapplied_effects_list.append(effect_data)
            
        metadata['unapplied_effects'] = unapplied_effects_list
        return metadata

    def fetch_and_parse(self, target_url, current_depth):
        """Core parsing logic adapted for the class structure."""
        xml_url = self.normalize_url(target_url)
        if not xml_url: return None
        
        # Prevent duplicate processing (especially important for base URLs vs data.xml variations)
        base_identifying_url = xml_url.replace('/data.xml', '')
        if base_identifying_url in self.visited_urls:
            return None
            
        self.visited_urls.add(base_identifying_url)
        
        safe_name = self.get_safe_filename(xml_url)
        cache_filepath = os.path.join('.cache', safe_name)
        
        # Cache Check
        if os.path.exists(cache_filepath):
            print(f"[{current_depth}] Loading from cache: {cache_filepath}")
            with open(cache_filepath, 'rb') as f:
                xml_content = f.read()
        else:
            print(f"[{current_depth}] Fetching network data: {xml_url}")
            try:
                response = requests.get(xml_url)
                response.raise_for_status()
                xml_content = response.content
                # Before writing to cache, let's beautify the XML for consistent formatting
                temp_soup = BeautifulSoup(xml_content, 'xml')
                xml_content = temp_soup.prettify(encoding='utf-8')
                with open(cache_filepath, 'wb') as f:
                    f.write(xml_content)
            except requests.exceptions.RequestException as e:
                print(f"Failed to fetch {xml_url}: {e}")
                return None
            
        soup = BeautifulSoup(xml_content, 'xml')
        identifier = self.extract_identifier(soup)
        metadata = self.extract_primary_metadata(soup)
        
        # Dynamically create the filepath based on the extracted year
        doc_year = metadata.get('year') or "unknown_year"
        year_dir = os.path.join(JSON_OUTPUT_DIR, str(doc_year))
        os.makedirs(year_dir, exist_ok=True)
        json_filepath = os.path.join(year_dir, safe_name.replace('.xml', '.json'))
        
        commentaries_map = {}
        found_citations = set() # Track new citations to queue
        
        for comm in soup.find_all('Commentary'):
            comm_id = comm.get('id')
            if not comm_id: continue
                
            full_text = comm.get_text(separator=" ", strip=True)
            citations = []
            
            for cit in comm.find_all('Citation'):
                cit_uri = cit.get('URI')
                citations.append({
                    "id": cit.get('id'),
                    "uri": cit_uri,
                    "title": cit.get('Title'),
                    "class": cit.get('Class'),
                    "year": cit.get('Year'),
                    "number": cit.get('Number'),
                    "text": cit.text.strip()
                })
                # If we haven't hit max depth, prepare to queue this citation
                if cit_uri and current_depth < self.max_depth:
                    found_citations.add(cit_uri)
                
            citation_subrefs = []
            for subref in comm.find_all('CitationSubRef'):
                citation_subrefs.append({
                    "id": subref.get('id'),
                    "uri": subref.get('URI'),
                    "citation_ref": subref.get('CitationRef'), 
                    "section_ref": subref.get('SectionRef'),
                    "text": subref.text.strip()
                })
                
            commentaries_map[comm_id] = {
                "type": comm.get('Type'),
                "text": full_text,
                "citations": citations,
                "citation_subrefs": citation_subrefs
            }

        # Document Tree Building (main body)
        document_tree = {}
        
        # Filter: Only grab P1s that are NOT inside the <Schedules> block
        body_p1s = [p1 for p1 in soup.find_all('P1') if not p1.find_parent('Schedules')]
        
        for section in body_p1s:
            part = section.find_parent('Part')
            chapter = section.find_parent('Chapter')
            p1group = section.find_parent('P1group') 
            
            part_num = part.find('Number').text.strip() if part and part.find('Number') else "No Part"
            part_title = part.find('Title').text.strip() if part and part.find('Title') else None
            chapter_uri = chapter.get('DocumentURI') if chapter else None
            chapter_num = chapter.find('Number').text.strip() if chapter and chapter.find('Number') else "No Chapter"
            chapter_title = chapter.find('Title').text.strip() if chapter and chapter.find('Title') else None
            
            chap_dict_key = chapter_uri or chapter_num
            
            if part_num not in document_tree:
                document_tree[part_num] = {"title": part_title, "chapters": {}}
                
            if chap_dict_key not in document_tree[part_num]["chapters"]:
                document_tree[part_num]["chapters"][chap_dict_key] = {
                    "chapter_uri": chapter_uri,
                    "chapter_number": chapter_num if chapter_num != "No Chapter" else None,
                    "title": chapter_title, 
                    "sections": []
                }
                
            section_num = section.find('Pnumber').text.strip() if section.find('Pnumber') else None
            section_title = p1group.find('Title').text.strip() if p1group and p1group.find('Title') else None
            
            section_commentaries = []
            for cref in section.find_all('CommentaryRef'):
                if cref.find_parent('P2') is None:
                    ref_id = cref.get('Ref')
                    if ref_id in commentaries_map:
                        section_commentaries.append({"ref_id": ref_id, **commentaries_map[ref_id]})

            section_data = {
                "section_number": section_num,
                "title": section_title,
                "uri": section.get('DocumentURI') or section.get('id'),
                "commentaries": section_commentaries,
                "paragraphs": []
            }
            
            paragraphs = section.find_all('P2')
            if not paragraphs:
                text_nodes = section.find_all('Text')
                section_data["text"] = " ".join([t.get_text(separator=" ", strip=True) for t in text_nodes])
            else:
                for para in paragraphs:
                    para_num = para.find('Pnumber').text.strip() if para.find('Pnumber') else None
                    para_text = " ".join([t.get_text(separator=" ", strip=True) for t in para.find_all('Text')])
                    
                    para_commentaries = []
                    for cref in para.find_all('CommentaryRef'):
                        ref_id = cref.get('Ref')
                        if ref_id in commentaries_map:
                            para_commentaries.append({"ref_id": ref_id, **commentaries_map[ref_id]})
                    
                    section_data["paragraphs"].append({
                        "paragraph_number": para_num,
                        "text": para_text,
                        "uri": para.get('DocumentURI') or para.get('id'),
                        "commentaries": para_commentaries
                    })
            
            document_tree[part_num]["chapters"][chap_dict_key]["sections"].append(section_data)

        # Document Tree Building (schedules)
        schedules_list = []
        schedules_root = soup.find('Schedules')
        
        if schedules_root:
            for schedule in schedules_root.find_all('Schedule'):
                sched_num = schedule.find('Number').text.strip() if schedule.find('Number') else None
                # Get the first Title tag (handles both <TitleBlock><Title> and direct <Title>)
                sched_title_node = schedule.find('Title')
                sched_title = sched_title_node.get_text(strip=True) if sched_title_node else None
                sched_ref = schedule.find('Reference').text.strip() if schedule.find('Reference') else None
                
                sched_obj = {
                    "schedule_number": sched_num,
                    "title": sched_title,
                    "reference": sched_ref,
                    "uri": schedule.get('DocumentURI') or schedule.get('id'),
                    "paragraphs": []
                }
                
                # In schedules, <P1> represents a paragraph
                for p1 in schedule.find_all('P1'):
                    p1_num = p1.find('Pnumber').text.strip() if p1.find('Pnumber') else None
                    
                    # Check for an enclosing <Pblock> (crossheading title)
                    pblock = p1.find_parent('Pblock')
                    pblock_title = pblock.find('Title').get_text(strip=True) if pblock and pblock.find('Title') else None
                    
                    p1_commentaries = []
                    for cref in p1.find_all('CommentaryRef'):
                        if cref.find_parent('P2') is None:
                            ref_id = cref.get('Ref')
                            if ref_id in commentaries_map:
                                p1_commentaries.append({"ref_id": ref_id, **commentaries_map[ref_id]})
                                
                    p1_data = {
                        "paragraph_number": p1_num,
                        "crossheading": pblock_title,
                        "uri": p1.get('DocumentURI') or p1.get('id'),
                        "commentaries": p1_commentaries,
                        "subparagraphs": []
                    }
                    
                    # In schedules, <P2> represents a sub-paragraph
                    p2s = p1.find_all('P2')
                    if not p2s:
                        p1_data["text"] = " ".join([t.get_text(separator=" ", strip=True) for t in p1.find_all('Text')])
                    else:
                        for p2 in p2s:
                            p2_num = p2.find('Pnumber').text.strip() if p2.find('Pnumber') else None
                            p2_text = " ".join([t.get_text(separator=" ", strip=True) for t in p2.find_all('Text')])
                            
                            p2_commentaries = []
                            for cref in p2.find_all('CommentaryRef'):
                                ref_id = cref.get('Ref')
                                if ref_id in commentaries_map:
                                    p2_commentaries.append({"ref_id": ref_id, **commentaries_map[ref_id]})
                            
                            p1_data["subparagraphs"].append({
                                "subparagraph_number": p2_num,
                                "text": p2_text,
                                "uri": p2.get('DocumentURI') or p2.get('id'),
                                "commentaries": p2_commentaries
                            })
                            
                    sched_obj["paragraphs"].append(p1_data)
                    
                schedules_list.append(sched_obj)

        # Assemble Final JSON
        final_json_structure = {
            "legislation_url": identifier.get('uri'),
            "identifier": identifier,
            "metadata": metadata, 
            "parts": [],
            "schedules": schedules_list  # Newly injected root array
        }
        
        # Assembly loop
        for p_num, p_data in document_tree.items():
            part_obj = {
                "part_number": p_num if p_num != "No Part" else None, 
                "title": p_data["title"], 
                "chapters": []
            }
            
            for chap_key, c_data in p_data["chapters"].items():
                chapter_obj = {
                    "uri": c_data["chapter_uri"], 
                    "chapter_number": c_data["chapter_number"], 
                    "title": c_data["title"], 
                    "sections": c_data["sections"]
                }
                part_obj["chapters"].append(chapter_obj)
                
            final_json_structure["parts"].append(part_obj)

        with open(json_filepath, 'w', encoding='utf-8') as f:
            f.write(json.dumps(final_json_structure, indent=4))
            
        # Add the found citations to our queue for the next loop
        for cit_url in found_citations:
            # Check if we've already seen the base identifying URL
            normalized = self.normalize_url(cit_url)
            if normalized and normalized.replace('/data.xml', '') not in self.visited_urls:
                self.queue.append((cit_url, current_depth + 1))

    def crawl(self, start_url):
        """
        Starts the queue processor.
        """
        self.queue.append((start_url, 0)) # Start at depth 0
        
        while self.queue:
            current_url, depth = self.queue.popleft()
            self.fetch_and_parse(current_url, depth)
            
        print(f"\nCrawl complete. Processed {len(self.visited_urls)} unique pieces of legislation.")

# %%
crawler = LegislationCrawler(max_depth=DEPTH_LIMIT)

# Read LEGISLATION_URI_LIST_FILE and process each URI
with open(LEGISLATION_URI_LIST_FILE, 'r') as f:
    legislation_uris = [line.strip() for line in f if line.strip()]
for uri in legislation_uris:
    full_url = f"{LEGISLATION_URL_PREFIX}{uri}"
    print(f"\nProcessing legislation: {full_url}")
    crawler.crawl(full_url)
# Out:
# Processing legislation: http://legislation.gov.uk/ukpga/2020/14
# [0] Fetching network data: http://legislation.gov.uk/ukpga/2020/14/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2022/531/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2025/1130/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2024/3/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2021/92/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2022/3/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2023/113/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2025/434/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2023/30/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2021/740/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2022/500/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2021/26/data.xml
#
# Crawl complete. Processed 12 unique pieces of legislation.
#
# Processing legislation: http://legislation.gov.uk/ukpga/2010/4
# [0] Fetching network data: http://legislation.gov.uk/ukpga/2010/4/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2018/79/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2018/464/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2012/952/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2019/105/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2016/898/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2018/78/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2012/2595/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/1815/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2025/1253/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2011/25/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2018/22/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2011/662/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2010/36/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2020/12/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ssi/2015/108/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2019/1087/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2010/33/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2010/2902/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2003/14/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2002/29/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2017/364/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2017/1072/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2024/286/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2017/22/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2023/53/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/wsi/2018/34/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2022/286/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2012/628/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2014/2228/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2018/3/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2017/32/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/744/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/460/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2011/2977/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/463/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2019/689/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2022/1174/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2015/725/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2015/33/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2014/7/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/wsi/2018/101/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2014/518/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2009/4/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/3209/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2018/1078/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2013/2/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2017/1271/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2023/402/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2012/736/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2013/29/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2017/855/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2011/245/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2020/1545/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2014/1962/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1992/12/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2007/3/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2023/98/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2011/2999/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/423/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2015/674/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2010/31/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2017/4/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2017/10/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2020/1495/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/asp/2013/11/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2020/26/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2014/21/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2010/8/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2021/724/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2006/964/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2011/24/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2022/734/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2016/24/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2012/266/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/1817/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2014/3327/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2012/21/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2005/5/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2012/1662/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2014/685/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2017/1179/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2003/1/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2021/716/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2012/700/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/1388/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2012/964/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2010/13/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/2819/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1994/23/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2012/14/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2014/26/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2011/2885/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2015/21/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1998/36/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2011/20/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/anaw/2017/1/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2012/2395/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2020/14/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2021/1270/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2015/11/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2009/2971/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2018/143/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2022/1321/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2010/4/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2022/40/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2019/1/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2019/818/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1981/63/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2022/31/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2010/665/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2011/11/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2022/465/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2012/57/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2023/518/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2024/555/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2011/1785/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2025/200/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2015/1938/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2006/3296/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2023/1399/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2014/14/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2019/63/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2019/1458/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2020/1/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2020/1642/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/636/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2025/8/data.xml
#
# Crawl complete. Processed 140 unique pieces of legislation.
#
# Processing legislation: http://legislation.gov.uk/ukpga/2007/3
# [0] Fetching network data: http://legislation.gov.uk/ukpga/2007/3/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2010/157/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2025/41/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2015/2035/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2009/10/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2016/771/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2007/11/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2016/74/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2014/1640/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2007/1820/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2012/1901/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2024/12/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2007/29/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2016/1161/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2017/396/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2023/1381/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2022/489/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2023/20/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2020/11/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2020/332/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2011/1037/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2007/18/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2009/1890/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2013/33/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2018/931/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/wsi/2016/413/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2022/283/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2010/582/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2014/29/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2011/22/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2017/468/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2017/1204/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2008/18/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2009/2035/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2019/710/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/1881/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2009/2859/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2007/2486/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2007/15/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2007/2532/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2016/11/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2009/2860/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2015/1810/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2009/317/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1988/1/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2009/3227/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2026/38/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2023/1/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2022/169/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2020/1499/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2024/897/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2022/487/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/1770/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2018/24/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2009/404/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2009/3250/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2007/940/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2018/459/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2009/403/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2014/6/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2021/224/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2010/2913/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/504/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2011/2459/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2016/1010/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2008/1821/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2002/2006/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1970/9/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2015/1836/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2018/892/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2012/23/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2020/1143/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2007/2483/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2008/9/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2017/1064/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2012/1896/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2022/572/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2014/768/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2008/3159/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2014/377/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/1772/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2023/393/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2009/56/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2022/493/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2019/201/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2008/839/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2008/2682/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2008/705/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2020/45/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2021/882/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1986/41/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/nisr/2009/128/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2009/3001/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2017/614/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2015/361/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2024/546/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2021/111/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2007/3506/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2009/23/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2008/954/data.xml
#
# Crawl complete. Processed 240 unique pieces of legislation.
#
# Processing legislation: http://legislation.gov.uk/ukpga/1992/12
# [0] Fetching network data: http://legislation.gov.uk/ukpga/1992/12/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2020/315/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2006/959/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2009/1604/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1998/1869/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1996/55/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1994/26/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1992/1874/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2006/575/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2001/57/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2008/17/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1995/4/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2014/605/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1993/236/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1927/41/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2008/1579/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1986/53/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1997/473/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2010/294/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/234/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1992/415/data.xml
# Failed to fetch http://www.legislation.gov.uk/uksi/1992/415/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk/uksi/1992/415/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1981/35/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2021/213/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1997/1154/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1996/846/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2005/1909/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/nisi/1994/2809/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2012/3044/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2011/5/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2001/9/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2005/22/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2007/17/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1997/1715/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1991/31/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1939/117/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1992/44/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/nisr/2015/49/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1978/18/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2017/495/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1997/41/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1984/51/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/1755/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2002/1970/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1962/46/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1995/171/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1986/56/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/nia/2011/25/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1989/26/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1999/16/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2011/4/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1997/16/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2016/1034/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1986/387/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1965/25/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1964/56/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2000/26/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2009/730/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1999/161/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2000/3316/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1994/3228/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2002/23/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2007/3546/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2004/2575/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2022/569/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2010/862/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1994/3226/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2004/2744/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1998/38/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1993/37/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1996/2325/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1998/2244/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1994/9/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2008/3068/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1992/3066/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2015/20/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2000/2957/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2011/701/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2010/614/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2004/1945/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2005/2014/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2005/4/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1983/28/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1994/21/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2016/481/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1968/13/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2000/38/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2002/1973/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1979/14/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2006/25/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2000/12/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/nisi/1979/1573/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1980/48/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2006/3291/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2010/2901/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1994/2550/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1972/65/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1975/22/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2005/14/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1995/37/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2000/17/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1996/8/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2022/230/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1998/3177/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2012/1868/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1920/18/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2008/2839/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2004/20/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1984/43/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2004/2200/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1995/3220/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1992/1655/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2015/1732/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1999/498/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1982/53/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2003/23/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1993/34/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1972/52/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2003/1900/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2008/381/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2001/3629/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2004/36/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1999/564/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1998/1870/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2008/2358/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2008/704/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1995/45/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2005/409/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2003/3142/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2012/1783/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2011/1211/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2014/956/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2004/12/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/apni/1964/28/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2006/3271/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/2242/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2005/1444/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/1400/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1989/469/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1978/30/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1999/3434/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2007/3402/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/nisi/1981/156/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2013/22/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1985/54/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1982/39/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2004/2310/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2005/1907/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2015/1540/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1997/991/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1994/728/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2008/3002/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2011/2329/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1990/29/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2007/2145/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1999/20/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1972/40/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1968/59/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2004/2199/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2003/21/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2007/2134/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2014/954/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2007/3186/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2005/7/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2010/670/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2005/3229/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1968/73/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1925/18/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1947/30/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1964/28/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1994/2189/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/wsi/2019/772/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1964/29/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1985/69/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1959/49/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1990/8/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2011/1431/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1999/29/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2011/2576/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1998/17/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2001/1149/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1992/48/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2001/2/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1970/10/data.xml
#
# Crawl complete. Processed 423 unique pieces of legislation.
#
# Processing legislation: http://legislation.gov.uk/ukpga/1993/23
# [0] Fetching network data: http://legislation.gov.uk/ukpga/1993/23/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1996/2959/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2000/3099/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/nisi/1988/1990/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1971/77/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2022/36/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2021/1281/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2001/2161/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1996/49/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1987/26/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2004/19/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2022/590/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2000/2444/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2005/565/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2003/754/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1996/52/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2000/464/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1996/2053/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2024/8/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1999/33/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2001/17/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1985/68/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1993/1655/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1996/2127/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/nisi/1983/1118/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1988/50/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2002/2815/data.xml
#
# Crawl complete. Processed 450 unique pieces of legislation.
#
# Processing legislation: http://legislation.gov.uk/ukpga/2015/1
# [0] Fetching network data: http://legislation.gov.uk/ukpga/2015/1/data.xml
#
# Crawl complete. Processed 451 unique pieces of legislation.
#
# Processing legislation: http://legislation.gov.uk/ukpga/2005/5
# [0] Fetching network data: http://legislation.gov.uk/ukpga/2005/5/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/wsi/2016/452/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2026/39/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2014/1042/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2008/14/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2009/3054/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2022/1278/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2005/2045/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2012/976/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2024/1289/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2005/1126/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2018/15/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2010/1158/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2014/3062/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2011/2581/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2022/1298/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1981/1/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2018/282/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2011/1740/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2008/23/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2008/561/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/1465/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2018/1079/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2017/2/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2015/2053/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2009/571/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2010/675/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2010/673/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ssi/2009/267/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2024/440/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2006/43/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2015/1539/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ssi/2012/99/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2015/635/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2009/270/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2007/949/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2010/813/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2009/2036/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2006/982/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2006/36/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2011/21/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2017/904/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2007/672/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2011/824/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2012/924/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ssi/2013/195/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2011/1043/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2017/1182/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2014/1283/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2014/992/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2010/530/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2010/2981/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2020/1449/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/wsi/2018/195/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/asp/2007/4/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2007/1050/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2015/374/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2009/2273/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2011/1157/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2017/446/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2005/11/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2014/889/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2010/17/data.xml
#
# Crawl complete. Processed 514 unique pieces of legislation.
#
# Processing legislation: http://legislation.gov.uk/ukpga/2003/1
# [0] Fetching network data: http://legislation.gov.uk/ukpga/2003/1/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2011/896/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2014/402/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2024/1012/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2010/2279/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2006/572/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2021/248/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2023/912/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2016/18/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2015/1537/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/nisr/2019/7/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2011/2696/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2004/1360/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2009/2888/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/630/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2024/901/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2019/1436/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/nisr/2017/44/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2016/1250/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2016/33/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2023/1012/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2017/373/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2015/33/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/nisr/2017/190/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2015/360/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2014/2461/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2015/8/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2020/1293/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2025/212/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/2657/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2015/1930/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2008/2170/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2011/1583/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2006/207/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2007/2478/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2021/1344/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2021/1341/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2006/32/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2006/18/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2006/133/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2015/346/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2007/3068/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2019/167/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/2796/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2016/407/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2010/495/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2015/101/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2014/209/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2007/1093/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2010/2317/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2021/886/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2012/821/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2024/374/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/1511/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2007/1388/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2009/1182/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/983/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/1133/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2011/775/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2010/15/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2010/1621/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ssi/2020/352/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/358/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2017/578/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2007/2130/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2005/2011/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/nisr/2016/236/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2015/634/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2023/1148/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2017/353/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2007/289/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2010/708/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2023/58/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2012/1360/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2010/2430/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2009/1171/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2001/1123/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2023/18/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2012/5/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2012/3004/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2022/529/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2008/3137/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/nia/2015/5/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2016/1036/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2008/836/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2024/1167/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2014/30/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2007/1081/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2010/1907/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2012/1319/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2025/52/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2014/2321/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2020/818/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2014/211/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/nisr/2018/138/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2024/356/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2022/4/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2014/1583/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2007/2194/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2014/3094/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/nisr/2017/216/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2006/246/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2017/16/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2014/3226/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2010/1187/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2003/1361/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/nisr/2025/176/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2010/231/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2012/764/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2007/849/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2008/787/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/nisi/2015/2006/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2014/859/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2019/902/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2019/1027/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2025/1148/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2014/606/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/nisr/2018/1/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/513/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2007/5/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/1126/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2006/1671/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2006/1963/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2003/1652/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2014/19/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/nisr/2018/97/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2009/1544/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/1250/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2017/338/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2024/287/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ssi/2021/174/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2015/886/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2017/297/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2005/770/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2013/2846/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2009/1357/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2018/308/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2014/28/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2023/1283/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2008/12/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2005/1091/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2003/1997/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/2012/7/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2014/2438/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2024/1349/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/2006/569/data.xml
#
# Crawl complete. Processed 660 unique pieces of legislation.
#
# Processing legislation: http://legislation.gov.uk/ukpga/1998/1
# [0] Fetching network data: http://legislation.gov.uk/ukpga/1998/1/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1998/30/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1996/56/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1998/2004/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1990/6/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/ukpga/1974/28/data.xml
# [1] Fetching network data: http://www.legislation.gov.uk/uksi/1998/210/data.xml
#
# Crawl complete. Processed 667 unique pieces of legislation.
#
# Processing legislation: http://legislation.gov.uk/ukpga/2025/1253
# [0] Fetching network data: http://legislation.gov.uk/ukpga/2025/1253/data.xml
# Failed to fetch http://legislation.gov.uk/ukpga/2025/1253/data.xml: 400 Client Error: Bad Request for url: https://www.legislation.gov.uk:443/ukpga/2025/1253/data.xml
#
# Crawl complete. Processed 668 unique pieces of legislation.
#
# Processing legislation: http://legislation.gov.uk/ukpga/2025/172
# [0] Fetching network data: http://legislation.gov.uk/ukpga/2025/172/data.xml
# Failed to fetch http://legislation.gov.uk/ukpga/2025/172/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk:443/ukpga/2025/172/data.xml
#
# Crawl complete. Processed 669 unique pieces of legislation.
#
# Processing legislation: http://legislation.gov.uk/ukpga/2023/221
# [0] Fetching network data: http://legislation.gov.uk/ukpga/2023/221/data.xml
# Failed to fetch http://legislation.gov.uk/ukpga/2023/221/data.xml: 404 Client Error: Not Found for url: https://www.legislation.gov.uk:443/ukpga/2023/221/data.xml
#
# Crawl complete. Processed 670 unique pieces of legislation.
#
# Processing legislation: http://legislation.gov.uk/ukpga/2022/1203
# [0] Fetching network data: http://legislation.gov.uk/ukpga/2022/1203/data.xml
# Failed to fetch http://legislation.gov.uk/ukpga/2022/1203/data.xml: 400 Client Error: Bad Request for url: https://www.legislation.gov.uk:443/ukpga/2022/1203/data.xml
#
# Crawl complete. Processed 671 unique pieces of legislation.
#
# Processing legislation: http://legislation.gov.uk/ukpga/2022/572
# [0] Fetching network data: http://legislation.gov.uk/ukpga/2022/572/data.xml
# Failed to fetch http://legislation.gov.uk/ukpga/2022/572/data.xml: 400 Client Error: Bad Request for url: https://www.legislation.gov.uk:443/ukpga/2022/572/data.xml
#
# Crawl complete. Processed 672 unique pieces of legislation.
